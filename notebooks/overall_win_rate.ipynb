# %%
import os
import pandas as pd
from dotenv import load_dotenv

from mktools.get_data import load_data_pd
from mktools.stats import calculate_npi, calculate_all_stats

load_dotenv()

# Load Data from the Google Sheet
df = load_data_pd(
    sheet_name="data",
    sheet_id=os.environ["SHEET_ID"],
    usecols=[
        "UID",
        "SUID",
        "NAME",
        "CHARACTER",
        "MAP",
        "PLACE",
        "PLAYERS",
        "DATE",
        "SEASON",
    ],
)

# %%
# Calculate the overall NPI number for each player per season per game type
npi_df = calculate_npi(initial_df=df)

npi_df
# Out:
#         NAME  PLACE  PLAYERS  SEASON  COUNT  TOTAL_PLAYED     PERCENT  \
# 0     Cooper      1        2       0     18            24   75.000000
# 1     Cooper      2        2       0      6            24   25.000000
# 2     Connor      1        2       0     21            31   67.741935
# 3     Connor      2        2       0     10            31   32.258065
# 4      Regan      1        2       0      7            11   63.636364
# ...      ...    ...      ...     ...    ...           ...         ...
# 1362  Graber      4        4      10      6             7   85.714286
# 1363  Graber      3        4      10      1             7   14.285714
# 1364   Randy      4        4      10      8             9   88.888889
# 1365   Randy      3        4      10      1             9   11.111111
# 1366  Kieran      4        4      10      2             2  100.000000
#
#       NPI_INTERMEDIATE       NPI
# 0             0.750000  1.250000
# 1             0.500000  1.250000
# 2             0.677419  1.322581
# 3             0.645161  1.322581
# 4             0.636364  1.363636
# ...                ...       ...
# 1362          3.428571  3.857143
# 1363          0.428571  3.857143
# 1364          3.555556  3.888889
# 1365          0.333333  3.888889
# 1366          4.000000  4.000000
#
# [1367 rows x 9 columns]

# %%
# Define the column name mappings for each possible place
place_dict = {1: "WINS", 2: "2NDS", 3: "3RDS", 4: "4THS"}

# Calculate the total stats values for each player, season and game type
all_stats_df = calculate_all_stats(
    initial_df=npi_df,
    place_mapping_ref=place_dict,
    wins_column=place_dict[1],
    seconds_column=place_dict[2],
    thirds_column=place_dict[3],
    fourths_column=place_dict[4],
)

# %%
def calculate_all_win_rates(stats_df: pd.DataFrame) -> pd.DataFrame:

    sdf = stats_df.copy()

    all_wr_df = (
        sdf.groupby(by=["NAME", "PLAYERS"])
        .agg(
            TOTAL_WINS=pd.NamedAgg("WINS", "sum"),
            TOTAL_GAMES_PLAYED=pd.NamedAgg("TOTAL_PLAYED", "sum"),
            OVERALL_WIN_RATE=pd.NamedAgg("WINS_PERCENTAGE", "mean"),
            OVERALL_2NDS=pd.NamedAgg("2NDS", "sum"),
            OVERALL_3RDS=pd.NamedAgg("3RDS", "sum"),
            OVERALL_4THS=pd.NamedAgg("4THS", "sum"),
            OVERALL_2NDS_RATE=pd.NamedAgg("2NDS_PERCENTAGE", "mean"),
            OVERALL_3RDS_RATE=pd.NamedAgg("3RDS_PERCENTAGE", "mean"),
            OVERALL_4THS_RATE=pd.NamedAgg("4THS_PERCENTAGE", "mean"),
        )
        .reset_index()
        .sort_values(
            by=[
                "PLAYERS",
                "OVERALL_WIN_RATE",
            ],
            ascending=[False, False],
        )
        .reset_index(drop=True)
    )

    return all_wr_df
# Out:
#         NAME  PLAYERS  TOTAL_WINS  TOTAL_GAMES_PLAYED  OVERALL_WIN_RATE  \
# 0     Cooper        4       811.0                1771         44.273049
# 1       Matt        4       428.0                1045         40.576899
# 2      Regan        4       440.0                1345         31.819209
# 3   Chandler        4        40.0                 141         31.694246
# 4       Luke        4        65.0                 244         28.824472
# ..       ...      ...         ...                 ...               ...
# 87   Domingo        2         0.0                   4          0.000000
# 88   Garrett        2         0.0                   2          0.000000
# 89     Randy        2         0.0                   1          0.000000
# 90    Robert        2         0.0                   1          0.000000
# 91       Sam        2         0.0                   2          0.000000
#
#     OVERALL_2NDS  OVERALL_3RDS  OVERALL_4THS  OVERALL_2NDS_RATE  \
# 0          451.0         301.0         208.0          26.617169
# 1          278.0         224.0         115.0          25.679362
# 2          382.0         336.0         187.0          28.768469
# 3           38.0          37.0          26.0          32.801472
# 4           74.0          60.0          45.0          31.341625
# ..           ...           ...           ...                ...
# 87           4.0           0.0           0.0         100.000000
# 88           2.0           0.0           0.0         100.000000
# 89           0.0           0.0           1.0           0.000000
# 90           1.0           0.0           0.0         100.000000
# 91           2.0           0.0           0.0         100.000000
#
#     OVERALL_3RDS_RATE  OVERALL_4THS_RATE
# 0           17.444565          11.665218
# 1           22.166837          11.576901
# 2           25.363452          14.048869
# 3           21.616909          13.887373
# 4           22.641234          17.192669
# ..                ...                ...
# 87           0.000000           0.000000
# 88           0.000000           0.000000
# 89           0.000000         100.000000
# 90           0.000000           0.000000
# 91           0.000000           0.000000
#
# [92 rows x 11 columns]

# %%
all_wr_df[all_wr_df["TOTAL_GAMES_PLAYED"] == all_wr_df["TOTAL_GAMES_PLAYED"].max()]
# Out:
#     NAME  PLAYERS  TOTAL_WINS  TOTAL_GAMES_PLAYED  OVERALL_WIN_RATE  \
# 7  Blake        4       467.0                2188         21.175623
#
#    OVERALL_2NDS  OVERALL_3RDS  OVERALL_4THS  OVERALL_2NDS_RATE  \
# 7         655.0         630.0         436.0          30.240596
#
#    OVERALL_3RDS_RATE  OVERALL_4THS_RATE
# 7          28.688485          19.895297

# %%
all_wr_df[all_wr_df["NAME"] == "Blake"]["TOTAL_GAMES_PLAYED"].sum()
# Out:
# 3918

# %%
all_wr_df[all_wr_df["NAME"] == "Martin"]
# Out:
#       NAME  PLAYERS  TOTAL_WINS  TOTAL_GAMES_PLAYED  OVERALL_WIN_RATE  \
# 12  Martin        4         1.0                  16          8.333333
# 65  Martin        3         0.0                   3          0.000000
#
#     OVERALL_2NDS  OVERALL_3RDS  OVERALL_4THS  OVERALL_2NDS_RATE  \
# 12           2.0           6.0           7.0               12.5
# 65           0.0           3.0           0.0                0.0
#
#     OVERALL_3RDS_RATE  OVERALL_4THS_RATE
# 12          43.055556          36.111111
# 65         100.000000           0.000000

# %%
all_wr_df[all_wr_df["NAME"] == "Cole"]["TOTAL_GAMES_PLAYED"].sum()
# Out:
# 2369

# %%
all_wr_df[all_wr_df["NAME"] == "Graber"]
# Out:
#       NAME  PLAYERS  TOTAL_WINS  TOTAL_GAMES_PLAYED  OVERALL_WIN_RATE  \
# 10  Graber        4        48.0                 309         11.442677
# 49  Graber        3        16.0                 131          7.535937
# 84  Graber        2         5.0                  28          9.010989
#
#     OVERALL_2NDS_RATE  OVERALL_3RDS_RATE  OVERALL_4THS_RATE
# 10          26.833027          26.075643          35.648653
# 49          45.658727          46.805336           0.000000
# 84          89.890110           1.098901           0.000000

# %%
all_wr_df[all_wr_df["NAME"] == "Domingo"]
# Out:
#        NAME  PLAYERS  TOTAL_WINS  TOTAL_GAMES_PLAYED  OVERALL_WIN_RATE  \
# 25  Domingo        4         0.0                 200               0.0
# 60  Domingo        3         0.0                  54               0.0
# 87  Domingo        2         0.0                   4               0.0
#
#     OVERALL_2NDS_RATE  OVERALL_3RDS_RATE  OVERALL_4THS_RATE
# 25           2.058233          18.988746          78.953021
# 60          17.083333          82.916667           0.000000
# 87         100.000000           0.000000           0.000000

# %%
first_place_df = npi_df[npi_df["PLACE"] == 1].copy()

# %%
df[df["PLAYERS"] == 1]
# Out:
# Empty DataFrame
# Columns: [UID, SUID, NAME, CHARACTER, MAP, PLACE, PLAYERS, DATE, SEASON]
# Index: []

# %%
first_place_df.groupby(by=["NAME", "PLAYERS"]).agg(
    OVERALL_WIN_RATE=pd.NamedAgg("PERCENT", "mean"),
    TOTAL_GAMES_PLAYED=pd.NamedAgg("TOTAL_PLAYED", "sum"),
).reset_index().sort_values(
    by=[
        "PLAYERS",
        "OVERALL_WIN_RATE",
    ],
    ascending=[False, False],
).reset_index(
    drop=True
)
# Out:
#         NAME  PLAYERS  OVERALL_WIN_RATE  TOTAL_GAMES_PLAYED
# 0     Martin        4         50.000000                   2
# 1     Cooper        4         44.273049                1771
# 2       Matt        4         40.576899                1045
# 3   Chandler        4         38.737412                 138
# 4     Konnor        4         34.521886                  49
# 5      Regan        4         31.819209                1345
# 6       Luke        4         31.706919                 231
# 7       Cole        4         27.185923                1415
# 8     Connor        4         21.454947                1472
# 9      Blake        4         21.175623                2188
# 10    Andrew        4         19.791667                  40
# 11    Graber        4         17.981350                 268
# 12    Miller        4         15.641173                  84
# 13       Ben        4         15.625000                  20
# 14    Caskey        4         14.285714                   7
# 15     Chloe        4         12.500000                   8
# 16    Hughes        4         11.111111                  18
# 17   Anthony        4          7.739899                 132
# 18      Joey        4          6.666667                  15
# 19   Triston        4          3.653378                 396
# 20      Jake        4          3.528829                 125
# 21    Colton        4          1.754386                  57
# 22    Cooper        3         54.436188                 793
# 23      Joey        3         50.000000                   2
# 24    Konnor        3         50.000000                   6
# 25     Regan        3         40.948359                 582
# 26  Chandler        3         40.701149                  64
# 27    Miller        3         40.000000                  14
# 28      Matt        3         39.101394                 407
# 29      Luke        3         38.472222                  59
# 30    Connor        3         33.230060                 711
# 31      Cole        3         30.352479                 663
# 32     Blake        3         29.235430                1165
# 33    Andrew        3         25.000000                   4
# 34    Graber        3         18.839842                  95
# 35    Colton        3         13.888889                  21
# 36   Anthony        3         13.333333                  26
# 37   Triston        3         10.017110                 188
# 38      Jake        3          7.957157                  53
# 39       Ben        3          7.692308                  13
# 40    Robert        3          1.960784                  51
# 41    Andrew        2        100.000000                   1
# 42    Konnor        2         83.333333                   4
# 43   Anthony        2         75.000000                   4
# 44      Luke        2         63.482143                  21
# 45    Cooper        2         62.242543                 476
# 46     Regan        2         57.926415                 261
# 47    Connor        2         55.947338                 204
# 48  Chandler        2         53.333333                  15
# 49      Cole        2         47.352101                 272
# 50      Matt        2         46.172840                  99
# 51     Blake        2         43.817195                 561
# 52       Ben        2         33.333333                   3
# 53    Miller        2         33.333333                   6
# 54    Graber        2         31.538462                  18
# 55   Triston        2         24.893162                  60
# 56      Jake        2         24.351852                  45
