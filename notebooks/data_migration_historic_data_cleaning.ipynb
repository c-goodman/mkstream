# %%
import os
import pandas as pd
from dotenv import load_dotenv
from multielo import MultiElo, Tracker
from mktools.get_data import load_data_pd
from mktools.validate_data import validate_bad_uids
import plotly.express as px
from alive_progress import alive_it
from bs4 import BeautifulSoup

# Load Variables from .env file
load_dotenv()

# Load data_main from google sheet
df = load_data_pd(
    sheet_name="data_main",
    sheet_id=os.environ["SHEET_ID"],
    usecols=[
        "UID",
        "SUID",
        "NAME",
        "CHARACTER",
        "MAP",
        "PLACE",
        "PLAYERS",
        "DATE",
        "SEASON",
    ],
)

# Convert date to string for... TODO: Update comment
df["DATE"] = pd.to_datetime(df["DATE"]).astype(str)

# Find UIDs that will break ELO calculation
invalid, valid = validate_bad_uids(df=df, return_valid=True)

vdf = valid.copy()

# %%
vdf
# Out:
#         UID  SUID     NAME CHARACTER              MAP  PLACE  PLAYERS  \
# 0         1     1     Cole      Toad     Sherbet Land      4        4
# 1         1     1   Connor     Yoshi     Sherbet Land      2        4
# 2         1     1   Cooper     Peach     Sherbet Land      1        4
# 3         1     1  Triston    Bowser     Sherbet Land      3        4
# 4         2     1     Cole      Toad  Kalimari Desert      4        4
# ...     ...   ...      ...       ...              ...    ...      ...
# 28520  8382   906   Connor     Peach     Yoshi Valley      2        3
# 28521  8382   906  Garrett      Toad     Yoshi Valley      3        3
# 28522  8383   906    Regan     Yoshi    D.K.'s Jungle      1        3
# 28523  8383   906    Blake     Peach    D.K.'s Jungle      2        3
# 28524  8383   906  Garrett      Toad    D.K.'s Jungle      3        3
#
#                       DATE  SEASON
# 0      2021-09-20 00:00:00       0
# 1      2021-09-20 00:00:00       0
# 2      2021-09-20 00:00:00       0
# 3      2021-09-20 00:00:00       0
# 4      2021-09-20 00:00:00       0
# ...                    ...     ...
# 28520  2025-01-05 22:27:59      15
# 28521  2025-01-05 22:27:59      15
# 28522  2025-01-05 23:09:11      15
# 28523  2025-01-05 23:09:11      15
# 28524  2025-01-05 23:09:11      15
#
# [28525 rows x 9 columns]

# %%
vdf.value_counts("UID").reset_index().UID.is_unique
# Out:
# True

# %%
vdf.UID.is_unique
# Out:
# False

# %%
vdf.columns
# Out:
# Index(['UID', 'SUID', 'NAME', 'CHARACTER', 'MAP', 'PLACE', 'PLAYERS', 'DATE',
#        'SEASON'],
#       dtype='object')

# %%
vdf["CHARACTER"].unique().tolist()
# Out:
# ['Toad', 'Yoshi', 'Peach', 'Bowser', 'Mario', 'Luigi', 'Wario', 'D.K.', nan]

# %%
for uid in vdf["UID"].unique():
    tdf = vdf[vdf["UID"] == uid].copy().reset_index(drop=True)

    character_cond = tdf["CHARACTER"].unique().shape[0] != tdf["PLAYERS"].max()

# %%
bad_dfs = []

for uid in vdf["UID"].unique():
    tdf = vdf[vdf["UID"] == uid].copy().reset_index(drop=True)

    name_cond = tdf["NAME"].unique().shape[0] != tdf["PLAYERS"].max()
    place_cond = tdf["PLACE"].unique().shape[0] != tdf["PLAYERS"].max()
    character_cond = tdf["CHARACTER"].unique().shape[0] != tdf["PLAYERS"].max()

    if name_cond & place_cond & character_cond:
        print("bad name, place and character")
        tdf["REASON"] = "name_place_character"
        bad_dfs.append(tdf)

    elif name_cond & place_cond & ~character_cond:
        print("bad name and place")
        tdf["REASON"] = "name_place"
        bad_dfs.append(tdf)

    elif name_cond & ~place_cond & character_cond:
        print("bad name and character")
        tdf["REASON"] = "name_character"
        bad_dfs.append(tdf)

    elif ~name_cond & place_cond & character_cond:
        print("bad place and character")
        tdf["REASON"] = "place_character"
        bad_dfs.append(tdf)

    elif name_cond:
        print("bad name")
        tdf["REASON"] = "name"
        bad_dfs.append(tdf)

    elif place_cond:
        print("bad place")
        tdf["REASON"] = "place"
        bad_dfs.append(tdf)

    elif character_cond:
        print("bad character")
        tdf["REASON"] = "character"
        bad_dfs.append(tdf)

bad_name_data = pd.concat(bad_dfs).reset_index(drop=True)
# Out:
# bad place
# bad character
# bad character
# bad name
# bad place
# bad character
# bad character
# bad character
# bad name and character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad name
# bad place
# bad place
# bad place
# bad character
# bad character
# bad character
# bad character
# bad character
# bad name
# bad place
# bad character
# bad character
# bad name
# bad character
# bad character
# bad name
# bad character
# bad name
# bad character
# bad character
# bad character
# bad name and place
# bad character
# bad character
# bad name
# bad name, place and character
# bad character
# bad character
# bad character
# bad character
# bad place
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad place and character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad name
# bad character
# bad character
# bad name
# bad name
# bad character
# bad character
# bad name and character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad name
# bad character
# bad character
# bad name
# bad character
# bad character
# bad character
# bad name
# bad character
# bad character
# bad character
# bad character
# bad character
# bad name
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad place
# bad place
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad name
# bad name
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character
# bad name
# bad character
# bad character
# bad character
# bad character
# bad name
# bad character
# bad name
# bad character
# bad character
# bad character
# bad character
# bad character
# bad character

# %%
bad_name_data.shape
# Out:
# (530, 10)

# %%
bad_name_data["UID"].unique().shape[0]
# Out:
# 141

# %%
bad_name_data.head(100)
# Out:
#      UID  SUID      NAME CHARACTER              MAP  PLACE  PLAYERS  \
# 0     33     3     Blake    Bowser    Wario Stadium      2        4
# 1     33     3    Connor      Toad    Wario Stadium      1        4
# 2     33     3    Cooper      D.K.    Wario Stadium      4        4
# 3     33     3     Regan     Peach    Wario Stadium      2        4
# 4     78     8     Blake    Bowser     Sherbet Land      3        4
# ..   ...   ...       ...       ...              ...    ...      ...
# 95  1147   125     Blake     Yoshi  Kalimari Desert      3        4
# 96  1147   125      Matt      Toad  Kalimari Desert      1        4
# 97  1181   130  Chandler    Bowser     Yoshi Valley      1        4
# 98  1181   130    Robert     Peach     Yoshi Valley      2        4
# 99  1181   130      Matt    Bowser     Yoshi Valley      3        4
#
#                    DATE  SEASON     REASON
# 0   2021-09-22 00:00:00       0      place
# 1   2021-09-22 00:00:00       0      place
# 2   2021-09-22 00:00:00       0      place
# 3   2021-09-22 00:00:00       0      place
# 4   2021-09-27 00:00:00       0  character
# ..                  ...     ...        ...
# 95  2022-01-13 00:00:00       1      place
# 96  2022-01-13 00:00:00       1      place
# 97  2022-01-18 00:00:00       1  character
# 98  2022-01-18 00:00:00       1  character
# 99  2022-01-18 00:00:00       1  character
#
# [100 rows x 10 columns]

# %%
bad_name_data.to_csv(
    rf"C:\Users\Cooper\sandbox\mkstream\form_data_migration\temp_bad_data.csv",
    index=False,
)

# %%
bad_name_data["REASON"].value_counts()
# Out:
# REASON
# character               408
# name                     71
# place                    33
# name_character            7
# name_place                4
# name_place_character      4
# place_character           3
# Name: count, dtype: int64

# %%
vdf_two = vdf[~vdf["UID"].isin(bad_name_data["UID"])].copy().reset_index(drop=True)

# %%
vdf_two_gdf = (
    vdf_two.sort_values(by=["SEASON", "SUID", "UID", "PLACE"])
    .groupby(by="UID")
    .agg(
        SUID=pd.NamedAgg("SUID", "first"),
        MAP=pd.NamedAgg("MAP", "first"),
        DATE=pd.NamedAgg("DATE", "first"),
        SEASON=pd.NamedAgg("SEASON", "first"),
    )
    .reset_index()
)

vdf_two_gdf
# Out:
#        UID  SUID              MAP                 DATE  SEASON
# 0        1     1     Sherbet Land  2021-09-20 00:00:00       0
# 1        2     1  Kalimari Desert  2021-09-20 00:00:00       0
# 2        3     1     Yoshi Valley  2021-09-20 00:00:00       0
# 3        4     1    Wario Stadium  2021-09-20 00:00:00       0
# 4        5     1   Choco Mountain  2021-09-20 00:00:00       0
# ...    ...   ...              ...                  ...     ...
# 8086  8379   906  Bowser's Castle  2025-01-05 19:38:45      15
# 8087  8380   906    D.K.'s Jungle  2025-01-05 19:55:31      15
# 8088  8381   906    Wario Stadium  2025-01-05 21:11:39      15
# 8089  8382   906     Yoshi Valley  2025-01-05 22:27:59      15
# 8090  8383   906    D.K.'s Jungle  2025-01-05 23:09:11      15
#
# [8091 rows x 5 columns]

# %%
df_wide_two_p = (
    vdf_two[vdf_two["PLAYERS"] == 2]
    .pivot(
        index=[
            "SEASON",
            "SUID",
            "UID",
            "PLAYERS",
            "MAP",
        ],
        columns=[
            "PLACE",
        ],
        values=["NAME", "CHARACTER", "DATE"],
    )
    .reset_index()
)

df_wide_two_p
# Out:
#       SEASON SUID   UID PLAYERS                MAP    NAME          CHARACTER  \
# PLACE                                                    1        2         1
# 0          0    3    36       2    Frappe Snowland  Cooper  Triston     Yoshi
# 1          0    8    75       2      Mario Raceway   Regan   Cooper     Peach
# 2          0   10   104       2      Wario Stadium   Blake   Connor     Yoshi
# 3          0   10   105       2      Wario Stadium   Blake   Connor     Peach
# 4          0   11   111       2    Bowser's Castle  Cooper  Triston     Wario
# ...      ...  ...   ...     ...                ...     ...      ...       ...
# 1214      15  899  8281       2      Mario Raceway  Konnor  Garrett     Yoshi
# 1215      15  899  8282       2       Moo Moo Farm  Konnor  Garrett     Yoshi
# 1216      15  899  8286       2    Toad's Turnpike  Konnor    Regan     Yoshi
# 1217      15  900  8295       2  Banshee Boardwalk   Regan     Cole     Yoshi
# 1218      15  906  8379       2    Bowser's Castle  Cooper    Blake     Peach
#
#                              DATE
# PLACE      2                    1                    2
# 0      Peach  2021-09-22 00:00:00  2021-09-22 00:00:00
# 1      Luigi  2021-09-27 00:00:00  2021-09-27 00:00:00
# 2      Peach  2021-09-29 00:00:00  2021-09-29 00:00:00
# 4931   2025-01-05 21:11:39  2025-01-05 21:11:39  2025-01-05 21:11:39
#
# [4932 rows x 17 columns]

# %%
simple = vdf[vdf.UID < 10].copy()

simple.head()
# Out:
#    UID  SUID     NAME CHARACTER              MAP  PLACE  PLAYERS  \
# 0    1     1     Cole      Toad     Sherbet Land      4        4
# 1    1     1   Connor     Yoshi     Sherbet Land      2        4
# 2    1     1   Cooper     Peach     Sherbet Land      1        4
# 3    1     1  Triston    Bowser     Sherbet Land      3        4
# 4    2     1     Cole      Toad  Kalimari Desert      4        4
#
#                   DATE  SEASON
# 0  2021-09-20 00:00:00       0
# 1  2021-09-20 00:00:00       0
# 2  2021-09-20 00:00:00       0
# 3  2021-09-20 00:00:00       0
# 4  2021-09-20 00:00:00       0

# %%
simple.pivot(
    index=[
        "SEASON",
        "SUID",
        "UID",
        "PLAYERS",
        "MAP",
    ],
    columns=[
        "PLACE",
    ],
    values=["NAME", "CHARACTER", "DATE"],
).reset_index()
# Out:
#       SEASON SUID UID PLAYERS                MAP    NAME                   \
# PLACE                                                  1       2        3
# 0          0    1   1       4       Sherbet Land  Cooper  Connor  Triston
# 1          0    1   2       4    Kalimari Desert  Cooper  Connor  Triston
# 2          0    1   3       4       Yoshi Valley  Cooper  Connor  Triston
# 3          0    1   4       4      Wario Stadium  Cooper    Cole    Blake
# 4          0    1   5       3     Choco Mountain  Cooper   Blake     Cole
# 5          0    1   6       4    Bowser's Castle  Connor    Cole   Cooper
# 6          0    1   7       4  Banshee Boardwalk   Blake    Matt   Cooper
# 7          0    1   8       3    Toad's Turnpike  Cooper   Blake     Matt
# 8          0    1   9       3      D.K.'s Jungle    Matt  Cooper    Blake
#
#               CHARACTER                                       DATE  \
# PLACE       4         1      2       3      4                    1
# 0        Cole     Peach  Yoshi  Bowser   Toad  2021-09-20 00:00:00
# 1        Cole     Yoshi  Peach  Bowser   Toad  2021-09-20 00:00:00
# 2        Cole      Toad  Peach  Bowser  Yoshi  2021-09-20 00:00:00
# 3      Connor     Mario   Toad   Peach  Yoshi  2021-09-20 00:00:00
# 4         NaN     Luigi  Yoshi   Peach    NaN  2021-09-20 00:00:00
# 5       Blake      Toad  Peach  Bowser  Yoshi  2021-09-20 00:00:00
# 6      Connor     Yoshi  Peach  Bowser   Toad  2021-09-20 00:00:00
# 7         NaN    Bowser  Yoshi    Toad    NaN  2021-09-20 00:00:00
# 8         NaN      Toad  Wario   Yoshi    NaN  2021-09-20 00:00:00
#
#
# PLACE                    2                    3                    4
# 0      2021-09-20 00:00:00  2021-09-20 00:00:00  2021-09-20 00:00:00
# 1      2021-09-20 00:00:00  2021-09-20 00:00:00  2021-09-20 00:00:00
# 2      2021-09-20 00:00:00  2021-09-20 00:00:00  2021-09-20 00:00:00
# 3      2021-09-20 00:00:00  2021-09-20 00:00:00  2021-09-20 00:00:00
# 4      2021-09-20 00:00:00  2021-09-20 00:00:00                  NaN
# 5      2021-09-20 00:00:00  2021-09-20 00:00:00  2021-09-20 00:00:00
# 6      2021-09-20 00:00:00  2021-09-20 00:00:00  2021-09-20 00:00:00
# 7      2021-09-20 00:00:00  2021-09-20 00:00:00                  NaN
# 8      2021-09-20 00:00:00  2021-09-20 00:00:00                  NaN

# %%
simple_gb = (
    simple.sort_values(by=["SEASON", "SUID", "UID", "PLACE"])
    .groupby(by="UID")
    .agg(
        SUID=pd.NamedAgg("SUID", "first"),
        MAP=pd.NamedAgg("MAP", "first"),
        PLAYERS=pd.NamedAgg("PLAYERS", "first"),
        DATE=pd.NamedAgg("DATE", "first"),
        SEASON=pd.NamedAgg("SEASON", "first"),
        NAME=pd.NamedAgg("NAME", list),
        PLACE=pd.NamedAgg("PLACE", list),
        CHARACTER=pd.NamedAgg("CHARACTER", list),
    )
    .reset_index()
)

simple_gb
# Out:
#    UID  SUID                MAP  PLAYERS                 DATE  SEASON  \
# 0    1     1       Sherbet Land        4  2021-09-20 00:00:00       0
# 1    2     1    Kalimari Desert        4  2021-09-20 00:00:00       0
# 2    3     1       Yoshi Valley        4  2021-09-20 00:00:00       0
# 3    4     1      Wario Stadium        4  2021-09-20 00:00:00       0
# 4    5     1     Choco Mountain        3  2021-09-20 00:00:00       0
# 5    6     1    Bowser's Castle        4  2021-09-20 00:00:00       0
# 6    7     1  Banshee Boardwalk        4  2021-09-20 00:00:00       0
# 7    8     1    Toad's Turnpike        3  2021-09-20 00:00:00       0
# 8    9     1      D.K.'s Jungle        3  2021-09-20 00:00:00       0
#
#                               NAME         PLACE                     CHARACTER
# 0  [Cooper, Connor, Triston, Cole]  [1, 2, 3, 4]  [Peach, Yoshi, Bowser, Toad]
# 1  [Cooper, Connor, Triston, Cole]  [1, 2, 3, 4]  [Yoshi, Peach, Bowser, Toad]
# 2  [Cooper, Connor, Triston, Cole]  [1, 2, 3, 4]  [Toad, Peach, Bowser, Yoshi]
# 3    [Cooper, Cole, Blake, Connor]  [1, 2, 3, 4]   [Mario, Toad, Peach, Yoshi]
# 4            [Cooper, Blake, Cole]     [1, 2, 3]         [Luigi, Yoshi, Peach]
# 5    [Connor, Cole, Cooper, Blake]  [1, 2, 3, 4]  [Toad, Peach, Bowser, Yoshi]
# 6    [Blake, Matt, Cooper, Connor]  [1, 2, 3, 4]  [Yoshi, Peach, Bowser, Toad]
# 7            [Cooper, Blake, Matt]     [1, 2, 3]         [Bowser, Yoshi, Toad]
# 8            [Matt, Cooper, Blake]     [1, 2, 3]          [Toad, Wario, Yoshi]

# %%
simple.melt(id_vars=["UID", "SUID", "SEASON"],)
# Out:
#      UID  SUID  SEASON variable                value
# 0      1     1       0     NAME                 Cole
# 1      1     1       0     NAME               Connor
# 2      1     1       0     NAME               Cooper
# 3      1     1       0     NAME              Triston
# 4      2     1       0     NAME                 Cole
# ..   ...   ...     ...      ...                  ...
# 193    8     1       0     DATE  2021-09-20 00:00:00
# 194    8     1       0     DATE  2021-09-20 00:00:00
# 195    9     1       0     DATE  2021-09-20 00:00:00
# 196    9     1       0     DATE  2021-09-20 00:00:00
# 197    9     1       0     DATE  2021-09-20 00:00:00
#
# [198 rows x 5 columns]

# %%
simple_gb[["UID", "NAME", "PLACE", "CHARACTER"]].explode(column="NAME")
# Out:
#    UID     NAME         PLACE                     CHARACTER
# 0    1   Cooper  [1, 2, 3, 4]  [Peach, Yoshi, Bowser, Toad]
# 0    1   Connor  [1, 2, 3, 4]  [Peach, Yoshi, Bowser, Toad]
# 0    1  Triston  [1, 2, 3, 4]  [Peach, Yoshi, Bowser, Toad]
# 0    1     Cole  [1, 2, 3, 4]  [Peach, Yoshi, Bowser, Toad]
# 1    2   Cooper  [1, 2, 3, 4]  [Yoshi, Peach, Bowser, Toad]
# 1    2   Connor  [1, 2, 3, 4]  [Yoshi, Peach, Bowser, Toad]
# 1    2  Triston  [1, 2, 3, 4]  [Yoshi, Peach, Bowser, Toad]
# 1    2     Cole  [1, 2, 3, 4]  [Yoshi, Peach, Bowser, Toad]
# 2    3   Cooper  [1, 2, 3, 4]  [Toad, Peach, Bowser, Yoshi]
# 2    3   Connor  [1, 2, 3, 4]  [Toad, Peach, Bowser, Yoshi]
# 2    3  Triston  [1, 2, 3, 4]  [Toad, Peach, Bowser, Yoshi]
# 2    3     Cole  [1, 2, 3, 4]  [Toad, Peach, Bowser, Yoshi]
# 3    4   Cooper  [1, 2, 3, 4]   [Mario, Toad, Peach, Yoshi]
# 3    4     Cole  [1, 2, 3, 4]   [Mario, Toad, Peach, Yoshi]
# 3    4    Blake  [1, 2, 3, 4]   [Mario, Toad, Peach, Yoshi]
# 3    4   Connor  [1, 2, 3, 4]   [Mario, Toad, Peach, Yoshi]
# 4    5   Cooper     [1, 2, 3]         [Luigi, Yoshi, Peach]
# 4    5    Blake     [1, 2, 3]         [Luigi, Yoshi, Peach]
# 4    5     Cole     [1, 2, 3]         [Luigi, Yoshi, Peach]
# 5    6   Connor  [1, 2, 3, 4]  [Toad, Peach, Bowser, Yoshi]
# 5    6     Cole  [1, 2, 3, 4]  [Toad, Peach, Bowser, Yoshi]
# 5    6   Cooper  [1, 2, 3, 4]  [Toad, Peach, Bowser, Yoshi]
# 5    6    Blake  [1, 2, 3, 4]  [Toad, Peach, Bowser, Yoshi]
# 6    7    Blake  [1, 2, 3, 4]  [Yoshi, Peach, Bowser, Toad]
# 6    7     Matt  [1, 2, 3, 4]  [Yoshi, Peach, Bowser, Toad]
# 6    7   Cooper  [1, 2, 3, 4]  [Yoshi, Peach, Bowser, Toad]
# 6    7   Connor  [1, 2, 3, 4]  [Yoshi, Peach, Bowser, Toad]
# 7    8   Cooper     [1, 2, 3]         [Bowser, Yoshi, Toad]
# 7    8    Blake     [1, 2, 3]         [Bowser, Yoshi, Toad]
# 7    8     Matt     [1, 2, 3]         [Bowser, Yoshi, Toad]
# 8    9     Matt     [1, 2, 3]          [Toad, Wario, Yoshi]
# 8    9   Cooper     [1, 2, 3]          [Toad, Wario, Yoshi]
# 8    9    Blake     [1, 2, 3]          [Toad, Wario, Yoshi]

# %%
simple = vdf[vdf.UID < 10].copy().reset_index()

simple.pivot(
    index="index",
    columns=[
        "PLAYERS",
# 8                    NaN       Yoshi Valley    NaN    0     NaN     Cole
# 9                    NaN       Yoshi Valley    NaN    0     NaN   Connor
# 10                   NaN       Yoshi Valley    NaN    0     NaN   Cooper
# 11                   NaN       Yoshi Valley    NaN    0     NaN  Triston
# 12                   NaN      Wario Stadium    NaN    0     NaN    Blake
# 13                   NaN      Wario Stadium    NaN    0     NaN     Cole
# 14                   NaN      Wario Stadium    NaN    0     NaN   Connor
# 15                   NaN      Wario Stadium    NaN    0     NaN   Cooper
# 16        Choco Mountain                NaN      0  NaN   Blake      NaN
# 17        Choco Mountain                NaN      0  NaN    Cole      NaN
# 18        Choco Mountain                NaN      0  NaN  Cooper      NaN
# 19                   NaN    Bowser's Castle    NaN    0     NaN    Blake
# 20                   NaN    Bowser's Castle    NaN    0     NaN     Cole
# 21                   NaN    Bowser's Castle    NaN    0     NaN   Connor
# 22                   NaN    Bowser's Castle    NaN    0     NaN   Cooper
# 23                   NaN  Banshee Boardwalk    NaN    0     NaN    Blake
# 24                   NaN  Banshee Boardwalk    NaN    0     NaN   Connor
# 25                   NaN  Banshee Boardwalk    NaN    0     NaN   Cooper
# 26                   NaN  Banshee Boardwalk    NaN    0     NaN     Matt
# 27       Toad's Turnpike                NaN      0  NaN   Blake      NaN
# 28       Toad's Turnpike                NaN      0  NaN  Cooper      NaN
# 29       Toad's Turnpike                NaN      0  NaN    Matt      NaN
# 30         D.K.'s Jungle                NaN      0  NaN   Blake      NaN
# 31         D.K.'s Jungle                NaN      0  NaN  Cooper      NaN
# 32         D.K.'s Jungle                NaN      0  NaN    Matt      NaN
#
#         CHARACTER         PLACE
# PLAYERS         3       4     3    4
# index
# 0             NaN    Toad   NaN    4
# 1             NaN   Yoshi   NaN    2
# 2             NaN   Peach   NaN    1
# 3             NaN  Bowser   NaN    3
# 4             NaN    Toad   NaN    4
# 5             NaN   Peach   NaN    2
# 6             NaN   Yoshi   NaN    1
# 7             NaN  Bowser   NaN    3
# 8             NaN   Yoshi   NaN    4
# 9             NaN   Peach   NaN    2
# 10            NaN    Toad   NaN    1
# 11            NaN  Bowser   NaN    3
# 12            NaN   Peach   NaN    3
# 13            NaN    Toad   NaN    2
# 14            NaN   Yoshi   NaN    4
# 15            NaN   Mario   NaN    1
# 16          Yoshi     NaN     2  NaN
# 17          Peach     NaN     3  NaN
# 18          Luigi     NaN     1  NaN
# 19            NaN   Yoshi   NaN    4
# 20            NaN   Peach   NaN    2
# 21            NaN    Toad   NaN    1
# 22            NaN  Bowser   NaN    3
# 23            NaN   Yoshi   NaN    1
# 24            NaN    Toad   NaN    4
# 25            NaN  Bowser   NaN    3
# 26            NaN   Peach   NaN    2
# 27          Yoshi     NaN     2  NaN
# 28         Bowser     NaN     1  NaN
# 29           Toad     NaN     3  NaN
# 30          Yoshi     NaN     3  NaN
# 31          Wario     NaN     2  NaN
# 32           Toad     NaN     1  NaN

# %%
df_wide = vdf[["UID", "DATE", "MAP"]].pivot(
    index="UID",
    columns=["MAP"],
)

df_wide

# %%
form_df = load_data_pd(sheet_name="form_data", sheet_id=os.environ["SHEET_ID"])

form_df = form_df.drop(
    columns=[x for x in form_df.columns if x.__contains__("Unnamed")]
)

form_df["Timestamp"] = pd.to_datetime(form_df["Timestamp"])

form_df.head()

# %%
form_df.columns = [
    x.replace(" ", "_").replace("[", "").replace("]", "") if x.__contains__("[") else x
    for x in form_df.columns
]

form_df

# %%
fdf = form_df.copy()

# %%
dfs = []

for game_type in [2, 3, 4]:
    tdf = fdf[fdf["PLAYERS"] == game_type].copy().reset_index(drop=True)

    dfs.append(tdf)

# %%
two_p = dfs[0]
three_p = dfs[1]
four_p = dfs[2]

two_p.head()

# %%
from typing import Literal


def transform_form_data(
    df: pd.DataFrame, game_type_replace_string: Literal["_2_", "_3_", "_4_"]
) -> pd.DataFrame:

    idf = df.copy()

    idf_out = (
        idf.dropna(axis=1, how="all")
        .reset_index(drop=True)
        .reset_index()
        .rename(columns={"index": "ID"})
    )

    idf_out.columns = [
        (
            x.replace(game_type_replace_string, "_")
            if x.__contains__(game_type_replace_string)
            else x.upper()
        )
        for x in idf_out.columns
    ]

    idf_out["TIMESTAMP"] = (
        pd.to_datetime(idf_out["TIMESTAMP"])
        .dt.tz_localize("US/Eastern")
        .dt.tz_convert("UTC")
    )

    idf_out["ID"] = idf_out["ID"] + 1

    return idf_out

# %%
two_p_out = transform_form_data(df=two_p, game_type_replace_string="_2_")
three_p_out = transform_form_data(df=three_p, game_type_replace_string="_3_")
four_p_out = transform_form_data(df=four_p, game_type_replace_string="_4_")

two_p_out

# %%
for idx, odf in enumerate([two_p_out, three_p_out, four_p_out]):
    v = idx + 2
    odf.to_csv(rf"C:\Users\Cooper\sandbox\mkstream\form_data_migration\data_{v}P.csv")

# %%
[len(x) for x in two_p_out["MAP"].unique()]

# %%
[len(x) for x in four_p_out["MAP"].unique()]

# %%
cat_df = (
    pd.concat([two_p_out, three_p_out, four_p_out])
    .sort_values(by="TIMESTAMP")
    .drop(columns=["ID"])
    .reset_index(drop=True)
    .reset_index()
    .rename(columns={"index": "ID"})
)

cat_df["ID"] = cat_df["ID"] + 1

cat_df.head()

# %%
cat_df.columns

# %%
cat_df_out = cat_df[
    [
        "ID",
        "TIMESTAMP",
        "NEW_SESSION",
        "MAP",
        "PLAYERS",
        "PLAYERS_1ST",
        "PLAYERS_2ND",
        "PLAYERS_3RD",
        "PLAYERS_4TH",
        "CHARACTERS_1ST",
        "CHARACTERS_2ND",
        "CHARACTERS_3RD",
        "CHARACTERS_4TH",
    ]
].copy()

# %%
cat_df_out

# %%
cat_df_out.to_csv(rf"C:\Users\Cooper\sandbox\mkstream\form_data_migration\form_data.csv", index=False)

# %%
cat_df_out.drop(columns=["ID"]).to_csv(rf"C:\Users\Cooper\sandbox\mkstream\form_data_migration\form_data_no_id_col.csv", index=False)

# %%
pd.Series([len(x) for x in four_p_out["CHARACTERS_1ST"].unique()]).max()

# %%
four_p_out["CHARACTERS_1ST"].unique()

# %%
pd.Series([len(x) for x in four_p_out["PLAYERS_1ST"].unique()]).max()
