# %%
import os
import pandas as pd
from dotenv import load_dotenv
from multielo import MultiElo, Tracker
from mktools.get_data import load_data_pd
from mktools.validate_data import validate_bad_uids
import plotly.express as px
from alive_progress import alive_it
from bs4 import BeautifulSoup

# Load Variables from .env file
load_dotenv()

# Load data_main from google sheet
df = load_data_pd(
    sheet_name="data_main",
    sheet_id=os.environ["SHEET_ID"],
    usecols=[
        "UID",
        "SUID",
        "NAME",
        "CHARACTER",
        "MAP",
        "PLACE",
        "PLAYERS",
        "DATE",
        "SEASON",
    ],
)

# Convert date to string for... TODO: Update comment
df["DATE"] = pd.to_datetime(df["DATE"]).astype(str)

# Find UIDs that will break ELO calculation
invalid, valid = validate_bad_uids(df=df, return_valid=True)

vdf = valid.copy()

# %%
vdf
# Out:
#         UID  SUID     NAME CHARACTER              MAP  PLACE  PLAYERS  \
# 0         1     1     Cole      Toad     Sherbet Land      4        4
# 1         1     1   Connor     Yoshi     Sherbet Land      2        4
# 2         1     1   Cooper     Peach     Sherbet Land      1        4
# 3         1     1  Triston    Bowser     Sherbet Land      3        4
# 4         2     1     Cole      Toad  Kalimari Desert      4        4
# ...     ...   ...      ...       ...              ...    ...      ...
# 26959  7969   862   Colton     Yoshi     Yoshi Valley      4        4
# 26960  7970   862    Blake      Toad    Wario Stadium      1        4
# 26961  7970   862  Domingo     Yoshi    Wario Stadium      2        4
# 26962  7970   862   Konnor    Bowser    Wario Stadium      3        4
# 26963  7970   862  Triston     Peach    Wario Stadium      4        4
#
#                       DATE  SEASON
# 0      2021-09-20 00:00:00       0
# 1      2021-09-20 00:00:00       0
# 2      2021-09-20 00:00:00       0
# 3      2021-09-20 00:00:00       0
# 4      2021-09-20 00:00:00       0
# ...                    ...     ...
# 26959  2024-11-21 22:13:09      14
# 26960  2024-11-22 00:03:49      14
# 26961  2024-11-22 00:03:49      14
# 26962  2024-11-22 00:03:49      14
# 26963  2024-11-22 00:03:49      14
#
# [26964 rows x 9 columns]

# %%
form_df = load_data_pd(sheet_name="form_data", sheet_id=os.environ["SHEET_ID"])

form_df = form_df.drop(
    columns=[x for x in form_df.columns if x.__contains__("Unnamed")]
)

form_df
# Out:
#                 Timestamp NEW_SESSION                 MAP  PLAYERS  \
# 0      7/17/2024 19:15:48          NO  Koopa Troopa Beach        3
# 1      7/17/2024 20:01:53          NO      Choco Mountain        4
# 2      7/17/2024 20:15:00          NO       D.K.'s Jungle        4
# 3      7/17/2024 20:42:27          NO     Kalimari Desert        4
# 4      7/17/2024 21:13:04          NO     Frappe Snowland        3
# ...                   ...         ...                 ...      ...
# 1670  11/21/2024 19:09:42          NO     Frappe Snowland        4
# 1671  11/21/2024 19:38:11          NO     Kalimari Desert        4
# 1672  11/21/2024 20:51:27          NO       Wario Stadium        4
# 1673  11/21/2024 22:13:09          NO        Yoshi Valley        4
# 1674   11/22/2024 0:03:49          NO       Wario Stadium        4
#
#      PLAYERS_2 [1ST] PLAYERS_2 [2ND] CHARACTERS_2 [1ST] CHARACTERS_2 [2ND]  \
# 0                NaN             NaN                NaN                NaN
# 1                NaN             NaN                NaN                NaN
# 2                NaN             NaN                NaN                NaN
# 3                NaN             NaN                NaN                NaN
# 4                NaN             NaN                NaN                NaN
# ...              ...             ...                ...                ...
# 1670             NaN             NaN                NaN                NaN
# 1671             NaN             NaN                NaN                NaN
# 1672             NaN             NaN                NaN                NaN
# 1673             NaN             NaN                NaN                NaN
# 1674             NaN             NaN                NaN                NaN
#
#      PLAYERS_3 [1ST] PLAYERS_3 [2ND]  ... CHARACTERS_3 [2ND]  \
# 0             Cooper           Regan  ...              Yoshi
# 1                NaN             NaN  ...                NaN
# 2                NaN             NaN  ...                NaN
# 3                NaN             NaN  ...                NaN
# 4             Cooper           Regan  ...               Toad
# ...              ...             ...  ...                ...
# 1670             NaN             NaN  ...                NaN
# 1671             NaN             NaN  ...                NaN
# 1672             NaN             NaN  ...                NaN
# 1673             NaN             NaN  ...                NaN
# 1674             NaN             NaN  ...                NaN
#
#      CHARACTERS_3 [3RD] PLAYERS_4 [1ST] PLAYERS_4 [2ND] PLAYERS_4 [3RD]  \
# 0                  Toad             NaN             NaN             NaN
# 1                   NaN          Cooper          Connor           Blake
# 2                   NaN            Cole           Regan          Cooper
# 3                   NaN           Regan            Cole          Cooper
# 4                 Peach             NaN             NaN             NaN
# ...                 ...             ...             ...             ...
# 1670                NaN           Regan          Connor            Cole
# 1671                NaN           Blake          Colton           Regan
# 1672                NaN           Regan          Connor           Blake
# 1673                NaN           Regan          Konnor         Domingo
# 1674                NaN           Blake         Domingo          Konnor
#
#      PLAYERS_4 [4TH] CHARACTERS_4 [1ST] CHARACTERS_4 [2ND] CHARACTERS_4 [3RD]  \
# 0                NaN                NaN                NaN                NaN
# 1            Triston              Luigi               Toad              Peach
# 2            Triston               Toad              Yoshi              Mario
# 3              Blake              Yoshi               Toad              Mario
# 4                NaN                NaN                NaN                NaN
# ...              ...                ...                ...                ...
# 1670         Domingo              Yoshi              Peach               Toad
# 1671           Sudur               Toad              Yoshi              Peach
# 1672          Colton               Toad              Peach              Yoshi
# 1673          Colton               Toad              Peach             Bowser
# 1674         Triston               Toad              Yoshi             Bowser
#
#      CHARACTERS_4 [4TH]
# 0                   NaN
# 1                 Yoshi
# 2                 Peach
# 3                 Peach
# 4                   NaN
# ...                 ...
# 1670             Bowser
# 1671               D.K.
# 1672              Mario
# 1673              Yoshi
# 1674              Peach
#
# [1675 rows x 22 columns]

# %%
form_df
# Out:
#                 Timestamp NEW_SESSION                 MAP  PLAYERS  \
# 0      7/17/2024 19:15:48          NO  Koopa Troopa Beach        3
# 1      7/17/2024 20:01:53          NO      Choco Mountain        4
# 2      7/17/2024 20:15:00          NO       D.K.'s Jungle        4
# 3      7/17/2024 20:42:27          NO     Kalimari Desert        4
# 4      7/17/2024 21:13:04          NO     Frappe Snowland        3
# ...                   ...         ...                 ...      ...
# 1670  11/21/2024 19:09:42          NO     Frappe Snowland        4
# 1671  11/21/2024 19:38:11          NO     Kalimari Desert        4
# 1672  11/21/2024 20:51:27          NO       Wario Stadium        4
# 1673  11/21/2024 22:13:09          NO        Yoshi Valley        4
# 1674   11/22/2024 0:03:49          NO       Wario Stadium        4
#
#      PLAYERS_2 [1ST] PLAYERS_2 [2ND] CHARACTERS_2 [1ST] CHARACTERS_2 [2ND]  \
# 0                NaN             NaN                NaN                NaN
# 1                NaN             NaN                NaN                NaN
# 2                NaN             NaN                NaN                NaN
# 3                NaN             NaN                NaN                NaN
# 4                NaN             NaN                NaN                NaN
# ...              ...             ...                ...                ...
# 1670             NaN             NaN                NaN                NaN
# 1671             NaN             NaN                NaN                NaN
# 1672             NaN             NaN                NaN                NaN
# 1673             NaN             NaN                NaN                NaN
# 1674             NaN             NaN                NaN                NaN
#
#      PLAYERS_3 [1ST] PLAYERS_3 [2ND]  ... CHARACTERS_3 [2ND]  \
# 0             Cooper           Regan  ...              Yoshi
# 1                NaN             NaN  ...                NaN
# 2                NaN             NaN  ...                NaN
# 3                NaN             NaN  ...                NaN
# 4             Cooper           Regan  ...               Toad
# ...              ...             ...  ...                ...
# 1670             NaN             NaN  ...                NaN
# 1671             NaN             NaN  ...                NaN
# 1672             NaN             NaN  ...                NaN
# 1673             NaN             NaN  ...                NaN
# 1674             NaN             NaN  ...                NaN
#
#      CHARACTERS_3 [3RD] PLAYERS_4 [1ST] PLAYERS_4 [2ND] PLAYERS_4 [3RD]  \
# 0                  Toad             NaN             NaN             NaN
# 1                   NaN          Cooper          Connor           Blake
# 2                   NaN            Cole           Regan          Cooper
# 3                   NaN           Regan            Cole          Cooper
# 4                 Peach             NaN             NaN             NaN
# ...                 ...             ...             ...             ...
# 1670                NaN           Regan          Connor            Cole
# 1671                NaN           Blake          Colton           Regan
# 1672                NaN           Regan          Connor           Blake
# 1673                NaN           Regan          Konnor         Domingo
# 1674                NaN           Blake         Domingo          Konnor
#
#      PLAYERS_4 [4TH] CHARACTERS_4 [1ST] CHARACTERS_4 [2ND] CHARACTERS_4 [3RD]  \
# 0                NaN                NaN                NaN                NaN
# 1            Triston              Luigi               Toad              Peach
# 2            Triston               Toad              Yoshi              Mario
# 3              Blake              Yoshi               Toad              Mario
# 4                NaN                NaN                NaN                NaN
# ...              ...                ...                ...                ...
# 1670         Domingo              Yoshi              Peach               Toad
# 1671           Sudur               Toad              Yoshi              Peach
# 1672          Colton               Toad              Peach              Yoshi
# 1673          Colton               Toad              Peach             Bowser
# 1674         Triston               Toad              Yoshi             Bowser
#
#      CHARACTERS_4 [4TH]
# 0                   NaN
# 1                 Yoshi
# 2                 Peach
# 3                 Peach
# 4                   NaN
# ...                 ...
# 1670             Bowser
# 1671               D.K.
# 1672              Mario
# 1673              Yoshi
# 1674              Peach
#
# [1675 rows x 22 columns]

# %%
form_df["Timestamp"] = pd.to_datetime(form_df["Timestamp"])

form_df
# Out:
#                Timestamp NEW_SESSION                 MAP  PLAYERS  \
# 0    2024-07-17 19:15:48          NO  Koopa Troopa Beach        3
# 1    2024-07-17 20:01:53          NO      Choco Mountain        4
# 2    2024-07-17 20:15:00          NO       D.K.'s Jungle        4
# 3    2024-07-17 20:42:27          NO     Kalimari Desert        4
# 4    2024-07-17 21:13:04          NO     Frappe Snowland        3
# ...                  ...         ...                 ...      ...
# 1670 2024-11-21 19:09:42          NO     Frappe Snowland        4
# 1671 2024-11-21 19:38:11          NO     Kalimari Desert        4
# 1672 2024-11-21 20:51:27          NO       Wario Stadium        4
# 1673 2024-11-21 22:13:09          NO        Yoshi Valley        4
# 1674 2024-11-22 00:03:49          NO       Wario Stadium        4
#
#      PLAYERS_2 [1ST] PLAYERS_2 [2ND] CHARACTERS_2 [1ST] CHARACTERS_2 [2ND]  \
# 0                NaN             NaN                NaN                NaN
# 1                NaN             NaN                NaN                NaN
# 2                NaN             NaN                NaN                NaN
# 3                NaN             NaN                NaN                NaN
# 4                NaN             NaN                NaN                NaN
# ...              ...             ...                ...                ...
# 1670             NaN             NaN                NaN                NaN
# 1671             NaN             NaN                NaN                NaN
# 1672             NaN             NaN                NaN                NaN
# 1673             NaN             NaN                NaN                NaN
# 1674             NaN             NaN                NaN                NaN
#
#      PLAYERS_3 [1ST] PLAYERS_3 [2ND]  ... CHARACTERS_3 [2ND]  \
# 0             Cooper           Regan  ...              Yoshi
# 1                NaN             NaN  ...                NaN
# 2                NaN             NaN  ...                NaN
# 3                NaN             NaN  ...                NaN
# 4             Cooper           Regan  ...               Toad
# ...              ...             ...  ...                ...
# 1670             NaN             NaN  ...                NaN
# 1671             NaN             NaN  ...                NaN
# 1672             NaN             NaN  ...                NaN
# 1673             NaN             NaN  ...                NaN
# 1674             NaN             NaN  ...                NaN
#
#      CHARACTERS_3 [3RD] PLAYERS_4 [1ST] PLAYERS_4 [2ND] PLAYERS_4 [3RD]  \
# 0                  Toad             NaN             NaN             NaN
# 1                   NaN          Cooper          Connor           Blake
# 2                   NaN            Cole           Regan          Cooper
# 3                   NaN           Regan            Cole          Cooper
# 4                 Peach             NaN             NaN             NaN
# ...                 ...             ...             ...             ...
# 1670                NaN           Regan          Connor            Cole
# 1671                NaN           Blake          Colton           Regan
# 1672                NaN           Regan          Connor           Blake
# 1673                NaN           Regan          Konnor         Domingo
# 1674                NaN           Blake         Domingo          Konnor
#
#      PLAYERS_4 [4TH] CHARACTERS_4 [1ST] CHARACTERS_4 [2ND] CHARACTERS_4 [3RD]  \
# 0                NaN                NaN                NaN                NaN
# 1            Triston              Luigi               Toad              Peach
# 2            Triston               Toad              Yoshi              Mario
# 3              Blake              Yoshi               Toad              Mario
# 4                NaN                NaN                NaN                NaN
# ...              ...                ...                ...                ...
# 1670         Domingo              Yoshi              Peach               Toad
# 1671           Sudur               Toad              Yoshi              Peach
# 1672          Colton               Toad              Peach              Yoshi
# 1673          Colton               Toad              Peach             Bowser
# 1674         Triston               Toad              Yoshi             Bowser
#
#      CHARACTERS_4 [4TH]
# 0                   NaN
# 1                 Yoshi
# 2                 Peach
# 3                 Peach
# 4                   NaN
# ...                 ...
# 1670             Bowser
# 1671               D.K.
# 1672              Mario
# 1673              Yoshi
# 1674              Peach
#
# [1675 rows x 22 columns]

# %%
form_df.columns
# Out:
# Index(['Timestamp', 'NEW_SESSION', 'MAP', 'PLAYERS', 'PLAYERS_2 [1ST]',
#        'PLAYERS_2 [2ND]', 'CHARACTERS_2 [1ST]', 'CHARACTERS_2 [2ND]',
#        'PLAYERS_3 [1ST]', 'PLAYERS_3 [2ND]', 'PLAYERS_3 [3RD]',
#        'CHARACTERS_3 [1ST]', 'CHARACTERS_3 [2ND]', 'CHARACTERS_3 [3RD]',
#        'PLAYERS_4 [1ST]', 'PLAYERS_4 [2ND]', 'PLAYERS_4 [3RD]',
#        'PLAYERS_4 [4TH]', 'CHARACTERS_4 [1ST]', 'CHARACTERS_4 [2ND]',
#        'CHARACTERS_4 [3RD]', 'CHARACTERS_4 [4TH]'],
#       dtype='object')

# %%
form_df.columns = [
    x.replace(" ", "_").replace("[", "").replace("]", "") if x.__contains__("[") else x
    for x in form_df.columns
]

form_df
# Out:
#                Timestamp NEW_SESSION                 MAP  PLAYERS  \
# 0    2024-07-17 19:15:48          NO  Koopa Troopa Beach        3
# 1    2024-07-17 20:01:53          NO      Choco Mountain        4
# 2    2024-07-17 20:15:00          NO       D.K.'s Jungle        4
# 3    2024-07-17 20:42:27          NO     Kalimari Desert        4
# 4    2024-07-17 21:13:04          NO     Frappe Snowland        3
# ...                  ...         ...                 ...      ...
# 1670 2024-11-21 19:09:42          NO     Frappe Snowland        4
# 1671 2024-11-21 19:38:11          NO     Kalimari Desert        4
# 1672 2024-11-21 20:51:27          NO       Wario Stadium        4
# 1673 2024-11-21 22:13:09          NO        Yoshi Valley        4
# 1674 2024-11-22 00:03:49          NO       Wario Stadium        4
#
#      PLAYERS_2_1ST PLAYERS_2_2ND CHARACTERS_2_1ST CHARACTERS_2_2ND  \
# 0              NaN           NaN              NaN              NaN
# 1              NaN           NaN              NaN              NaN
# 2              NaN           NaN              NaN              NaN
# 3              NaN           NaN              NaN              NaN
# 4              NaN           NaN              NaN              NaN
# ...            ...           ...              ...              ...
# 1670           NaN           NaN              NaN              NaN
# 1671           NaN           NaN              NaN              NaN
# 1672           NaN           NaN              NaN              NaN
# 1673           NaN           NaN              NaN              NaN
# 1674           NaN           NaN              NaN              NaN
#
#      PLAYERS_3_1ST PLAYERS_3_2ND  ... CHARACTERS_3_2ND CHARACTERS_3_3RD  \
# 0           Cooper         Regan  ...            Yoshi             Toad
# 1              NaN           NaN  ...              NaN              NaN
# 2              NaN           NaN  ...              NaN              NaN
# 3              NaN           NaN  ...              NaN              NaN
# 4           Cooper         Regan  ...             Toad            Peach
# ...            ...           ...  ...              ...              ...
# 1670           NaN           NaN  ...              NaN              NaN
# 1671           NaN           NaN  ...              NaN              NaN
# 1672           NaN           NaN  ...              NaN              NaN
# 1673           NaN           NaN  ...              NaN              NaN
# 1674           NaN           NaN  ...              NaN              NaN
#
#      PLAYERS_4_1ST PLAYERS_4_2ND PLAYERS_4_3RD PLAYERS_4_4TH CHARACTERS_4_1ST  \
# 0              NaN           NaN           NaN           NaN              NaN
# 1           Cooper        Connor         Blake       Triston            Luigi
# 2             Cole         Regan        Cooper       Triston             Toad
# 3            Regan          Cole        Cooper         Blake            Yoshi
# 4              NaN           NaN           NaN           NaN              NaN
# ...            ...           ...           ...           ...              ...
# 1670         Regan        Connor          Cole       Domingo            Yoshi
# 1671         Blake        Colton         Regan         Sudur             Toad
# 1672         Regan        Connor         Blake        Colton             Toad
# 1673         Regan        Konnor       Domingo        Colton             Toad
# 1674         Blake       Domingo        Konnor       Triston             Toad
#
#      CHARACTERS_4_2ND CHARACTERS_4_3RD CHARACTERS_4_4TH
# 0                 NaN              NaN              NaN
# 1                Toad            Peach            Yoshi
# 2               Yoshi            Mario            Peach
# 3                Toad            Mario            Peach
# 4                 NaN              NaN              NaN
# ...               ...              ...              ...
# 1670            Peach             Toad           Bowser
# 1671            Yoshi            Peach             D.K.
# 1672            Peach            Yoshi            Mario
# 1673            Peach           Bowser            Yoshi
# 1674            Yoshi           Bowser            Peach
#
# [1675 rows x 22 columns]

# %%
fdf = form_df.copy()

# %%
dfs = []

for game_type in [2, 3, 4]:
    tdf = fdf[fdf["PLAYERS"] == game_type].copy().reset_index(drop=True)

    dfs.append(tdf)

# %%
two_p = dfs[0]
three_p = dfs[1]
four_p = dfs[2]

two_p
# Out:
#               Timestamp NEW_SESSION              MAP  PLAYERS PLAYERS_2_1ST  \
# 0   2024-07-18 21:05:00          NO  Toad's Turnpike        2        Cooper
# 1   2024-07-21 16:32:47         YES  Bowser's Castle        2          Matt
# 2   2024-07-21 16:56:38          NO     Yoshi Valley        2          Matt
# 3   2024-07-24 13:46:27         YES    Wario Stadium        2         Regan
# 4   2024-07-24 13:47:06          NO  Toad's Turnpike        2         Regan
# ..                  ...         ...              ...      ...           ...
# 111 2024-11-06 02:55:25          NO  Frappe Snowland        2        Konnor
# 112 2024-11-08 00:37:30          NO    D.K.'s Jungle        2         Regan
# 113 2024-11-08 00:45:44          NO  Toad's Turnpike        2         Regan
# 114 2024-11-08 01:12:53          NO  Toad's Turnpike        2         Regan
# 115 2024-11-09 00:42:02          NO    Royal Raceway        2        Konnor
#
#     PLAYERS_2_2ND CHARACTERS_2_1ST CHARACTERS_2_2ND PLAYERS_3_1ST  \
# 0           Regan            Peach             Toad           NaN
# 1          Cooper             Toad            Peach           NaN
# 2          Cooper            Peach            Yoshi           NaN
# 3          Martin             Toad            Yoshi           NaN
# 4          Martin             D.K.            Yoshi           NaN
# ..            ...              ...              ...           ...
# 111         Regan            Yoshi             Toad           NaN
# 112       Domingo             Toad            Peach           NaN
# 113       Domingo            Peach             Toad           NaN
# 114        Connor            Peach             Toad           NaN
# 115       Domingo            Peach             Toad           NaN
#
#     PLAYERS_3_2ND  ... CHARACTERS_3_2ND CHARACTERS_3_3RD PLAYERS_4_1ST  \
# 0             NaN  ...              NaN              NaN           NaN
# 1             NaN  ...              NaN              NaN           NaN
# 2             NaN  ...              NaN              NaN           NaN
# 3             NaN  ...              NaN              NaN           NaN
# 4             NaN  ...              NaN              NaN           NaN
# ..            ...  ...              ...              ...           ...
# 111           NaN  ...              NaN              NaN           NaN
# 112           NaN  ...              NaN              NaN           NaN
# 113           NaN  ...              NaN              NaN           NaN
# 114           NaN  ...              NaN              NaN           NaN
# 115           NaN  ...              NaN              NaN           NaN
#
#     PLAYERS_4_2ND PLAYERS_4_3RD PLAYERS_4_4TH CHARACTERS_4_1ST  \
# 0             NaN           NaN           NaN              NaN
# 1             NaN           NaN           NaN              NaN
# 2             NaN           NaN           NaN              NaN
# 3             NaN           NaN           NaN              NaN
# 4             NaN           NaN           NaN              NaN
# ..            ...           ...           ...              ...
# 111           NaN           NaN           NaN              NaN
# 112           NaN           NaN           NaN              NaN
# 113           NaN           NaN           NaN              NaN
# 114           NaN           NaN           NaN              NaN
# 115           NaN           NaN           NaN              NaN
#
#     CHARACTERS_4_2ND CHARACTERS_4_3RD CHARACTERS_4_4TH
# 0                NaN              NaN              NaN
# 1                NaN              NaN              NaN
# 2                NaN              NaN              NaN
# 3                NaN              NaN              NaN
# 4                NaN              NaN              NaN
# ..               ...              ...              ...
# 111              NaN              NaN              NaN
# 112              NaN              NaN              NaN
# 113              NaN              NaN              NaN
# 114              NaN              NaN              NaN
# 115              NaN              NaN              NaN
#
# [116 rows x 22 columns]

# %%
two_p.columns
# Out:
# Index(['Timestamp', 'NEW_SESSION', 'MAP', 'PLAYERS', 'PLAYERS_2_1ST',
#        'PLAYERS_2_2ND', 'CHARACTERS_2_1ST', 'CHARACTERS_2_2ND',
#        'PLAYERS_3_1ST', 'PLAYERS_3_2ND', 'PLAYERS_3_3RD', 'CHARACTERS_3_1ST',
#        'CHARACTERS_3_2ND', 'CHARACTERS_3_3RD', 'PLAYERS_4_1ST',
#        'PLAYERS_4_2ND', 'PLAYERS_4_3RD', 'PLAYERS_4_4TH', 'CHARACTERS_4_1ST',
#        'CHARACTERS_4_2ND', 'CHARACTERS_4_3RD', 'CHARACTERS_4_4TH'],
#       dtype='object')

# %%
two_p_out = (
    two_p.dropna(axis=1, how="all")
    .reset_index(drop=True)
    .reset_index()
    .rename(columns={"index": "ID"})
)

two_p_out.columns = [
    x.replace("_2_", "_") if x.__contains__("_2_") else x for x in two_p_out.columns
]

two_p_out["ID"] = two_p_out["ID"] + 1

two_p_out
# Out:
#       ID           Timestamp NEW_SESSION              MAP  PLAYERS  \
# 0      1 2024-07-18 21:05:00          NO  Toad's Turnpike        2
# 1      2 2024-07-21 16:32:47         YES  Bowser's Castle        2
# 2      3 2024-07-21 16:56:38          NO     Yoshi Valley        2
# 3      4 2024-07-24 13:46:27         YES    Wario Stadium        2
# 4      5 2024-07-24 13:47:06          NO  Toad's Turnpike        2
# ..   ...                 ...         ...              ...      ...
# 111  112 2024-11-06 02:55:25          NO  Frappe Snowland        2
# 112  113 2024-11-08 00:37:30          NO    D.K.'s Jungle        2
# 113  114 2024-11-08 00:45:44          NO  Toad's Turnpike        2
# 114  115 2024-11-08 01:12:53          NO  Toad's Turnpike        2
# 115  116 2024-11-09 00:42:02          NO    Royal Raceway        2
#
#     PLAYERS_1ST PLAYERS_2ND CHARACTERS_1ST CHARACTERS_2ND
# 0        Cooper       Regan          Peach           Toad
# 1          Matt      Cooper           Toad          Peach
# 2          Matt      Cooper          Peach          Yoshi
# 3         Regan      Martin           Toad          Yoshi
# 4         Regan      Martin           D.K.          Yoshi
# ..          ...         ...            ...            ...
# 111      Konnor       Regan          Yoshi           Toad
# 112       Regan     Domingo           Toad          Peach
# 113       Regan     Domingo          Peach           Toad
# 114       Regan      Connor          Peach           Toad
# 115      Konnor     Domingo          Peach           Toad
#
# [116 rows x 9 columns]

# %%
three_p_out = (
    three_p.dropna(axis=1, how="all")
    .reset_index(drop=True)
    .reset_index()
    .rename(columns={"index": "ID"})
)

three_p_out.columns = [
    x.replace("_3_", "_") if x.__contains__("_3_") else x for x in three_p_out.columns
]

three_p_out["ID"] = three_p_out["ID"] + 1

three_p_out
# Out:
#       ID           Timestamp NEW_SESSION                 MAP  PLAYERS  \
# 0      1 2024-07-17 19:15:48          NO  Koopa Troopa Beach        3
# 1      2 2024-07-17 21:13:04          NO     Frappe Snowland        3
# 2      3 2024-07-18 19:42:21          NO        Sherbet Land        3
# 3      4 2024-07-18 22:38:14          NO  Koopa Troopa Beach        3
# 4      5 2024-07-20 18:46:58          NO     Kalimari Desert        3
# ..   ...                 ...         ...                 ...      ...
# 138  139 2024-11-02 15:32:05          NO       D.K.'s Jungle        3
# 139  140 2024-11-08 13:41:04         YES     Toad's Turnpike        3
# 140  141 2024-11-16 12:10:00         YES  Koopa Troopa Beach        3
# 141  142 2024-11-16 23:53:58          NO       Mario Raceway        3
# 142  143 2024-11-21 17:22:51         YES        Yoshi Valley        3
#
#     PLAYERS_1ST PLAYERS_2ND PLAYERS_3RD CHARACTERS_1ST CHARACTERS_2ND  \
# 0        Cooper       Regan     Garrett          Peach          Yoshi
# 1        Cooper       Regan       Blake          Mario           Toad
# 2         Regan       Blake      Cooper          Yoshi          Peach
# 3         Regan      Cooper      Konnor          Peach           Toad
# 4         Regan     Triston      Cooper          Peach          Yoshi
# ..          ...         ...         ...            ...            ...
# 138        Matt        Luke     Antonio          Yoshi           Toad
# 139       Blake       Regan        Matt           Toad          Yoshi
# 140    Chandler        Luke      Robert          Yoshi          Peach
# 141      Konnor       Blake        Jake          Peach          Yoshi
# 142       Regan        Matt        Cole           Toad          Yoshi
#
#     CHARACTERS_3RD
# 0             Toad
# 1            Peach
# 2             Toad
# 3            Yoshi
# 4            Mario
# ..             ...
# 138          Peach
# 139          Peach
# 140           Toad
# 141           Toad
# 142          Peach
#
# [143 rows x 11 columns]

# %%
four_p_out = (
    four_p.dropna(axis=1, how="all")
    .reset_index(drop=True)
    .reset_index()
    .rename(columns={"index": "ID"})
)

four_p_out.columns = [
    x.replace("_3_", "_") if x.__contains__("_3_") else x.upper()
    for x in four_p_out.columns
]

four_p_out["ID"] = four_p_out["ID"] + 1

four_p_out
# Out:
#         ID           TIMESTAMP NEW_SESSION                 MAP  PLAYERS  \
# 0        1 2024-07-17 20:01:53          NO      Choco Mountain        4
# 1        2 2024-07-17 20:15:00          NO       D.K.'s Jungle        4
# 2        3 2024-07-17 20:42:27          NO     Kalimari Desert        4
# 3        4 2024-07-17 23:25:28          NO  Koopa Troopa Beach        4
# 4        5 2024-07-17 23:40:49          NO       Wario Stadium        4
# ...    ...                 ...         ...                 ...      ...
# 1411  1412 2024-11-21 19:09:42          NO     Frappe Snowland        4
# 1412  1413 2024-11-21 19:38:11          NO     Kalimari Desert        4
# 1413  1414 2024-11-21 20:51:27          NO       Wario Stadium        4
# 1414  1415 2024-11-21 22:13:09          NO        Yoshi Valley        4
# 1415  1416 2024-11-22 00:03:49          NO       Wario Stadium        4
#
#      PLAYERS_4_1ST PLAYERS_4_2ND PLAYERS_4_3RD PLAYERS_4_4TH CHARACTERS_4_1ST  \
# 0           Cooper        Connor         Blake       Triston            Luigi
# 1             Cole         Regan        Cooper       Triston             Toad
# 2            Regan          Cole        Cooper         Blake            Yoshi
# 3           Cooper         Blake       Triston        Connor            Wario
# 4            Blake        Cooper       Triston         Regan             Toad
# ...            ...           ...           ...           ...              ...
# 1411         Regan        Connor          Cole       Domingo            Yoshi
# 1412         Blake        Colton         Regan         Sudur             Toad
# 1413         Regan        Connor         Blake        Colton             Toad
# 1414         Regan        Konnor       Domingo        Colton             Toad
# 1415         Blake       Domingo        Konnor       Triston             Toad
#
#      CHARACTERS_4_2ND CHARACTERS_4_3RD CHARACTERS_4_4TH
# 0                Toad            Peach            Yoshi
# 1               Yoshi            Mario            Peach
# 2                Toad            Mario            Peach
# 3                Toad            Peach            Yoshi
# 4                D.K.            Peach            Yoshi
# ...               ...              ...              ...
# 1411            Peach             Toad           Bowser
# 1412            Yoshi            Peach             D.K.
# 1413            Peach            Yoshi            Mario
# 1414            Peach           Bowser            Yoshi
# 1415            Yoshi           Bowser            Peach
#
# [1416 rows x 13 columns]

# %%
for idx, odf in enumerate([two_p_out, three_p_out, four_p_out]):
    v = idx + 2
    odf.to_csv(rf"C:\Users\Cooper\sandbox\mkstream\form_data_migration\data_{v}P.csv")

# %%
form_df.dtypes
# Out:
# Timestamp             object
# NEW_SESSION           object
# MAP                   object
# PLAYERS                int64
# PLAYERS_2 [1ST]       object
# PLAYERS_2 [2ND]       object
# CHARACTERS_2 [1ST]    object
# CHARACTERS_2 [2ND]    object
# PLAYERS_3 [1ST]       object
# PLAYERS_3 [2ND]       object
# PLAYERS_3 [3RD]       object
# CHARACTERS_3 [1ST]    object
# CHARACTERS_3 [2ND]    object
# CHARACTERS_3 [3RD]    object
# PLAYERS_4 [1ST]       object
# PLAYERS_4 [2ND]       object
# PLAYERS_4 [3RD]       object
# PLAYERS_4 [4TH]       object
# CHARACTERS_4 [1ST]    object
# CHARACTERS_4 [2ND]    object
# CHARACTERS_4 [3RD]    object
# CHARACTERS_4 [4TH]    object
# dtype: object

# %%
vdf.dtypes
# Out:
# UID           int64
# SUID          int64
# NAME         object
# CHARACTER    object
# MAP          object
# PLACE         int64
# PLAYERS       int64
# DATE         object
# SEASON        int64
# dtype: object

# %%
vdf.DATE.dtype
# Out:
# dtype('O')

# %%
vdf.DATE[0]
# Out:
# '2021-09-20 00:00:00'
