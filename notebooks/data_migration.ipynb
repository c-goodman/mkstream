# %%
import os
import numpy as np
import pandas as pd
from dotenv import load_dotenv
from multielo import MultiElo, Tracker
from mktools.get_data import load_data_pd
from mktools.validate_data import validate_bad_uids
import plotly.express as px
from alive_progress import alive_it
from bs4 import BeautifulSoup

# Load Variables from .env file
load_dotenv()
# Out:
# True

# %%
form_df = load_data_pd(sheet_name="form_data", sheet_id=os.environ["SHEET_ID"])

form_df = form_df.drop(
    columns=[
        x
        for x in form_df.columns
        if x.__contains__("Unnamed") or x.__contains__("Score")
    ]
)

form_df["Timestamp"] = pd.to_datetime(form_df["Timestamp"])

form_df.head()
# Out:
#             Timestamp NEW_SESSION                 MAP  PLAYERS  \
# 0 2024-07-17 19:15:48          NO  Koopa Troopa Beach        3
# 1 2024-07-17 20:01:53          NO      Choco Mountain        4
# 2 2024-07-17 20:15:00          NO       D.K.'s Jungle        4
# 3 2024-07-17 20:42:27          NO     Kalimari Desert        4
# 4 2024-07-17 21:13:04          NO     Frappe Snowland        3
#
#   PLAYERS_2 [1ST] PLAYERS_2 [2ND] CHARACTERS_2 [1ST] CHARACTERS_2 [2ND]  \
# 0             NaN             NaN                NaN                NaN
# 1             NaN             NaN                NaN                NaN
# 2             NaN             NaN                NaN                NaN
# 3             NaN             NaN                NaN                NaN
# 4             NaN             NaN                NaN                NaN
#
#   PLAYERS_3 [1ST] PLAYERS_3 [2ND]  ... CHARACTERS_3 [2ND] CHARACTERS_3 [3RD]  \
# 0          Cooper           Regan  ...              Yoshi               Toad
# 1             NaN             NaN  ...                NaN                NaN
# 2             NaN             NaN  ...                NaN                NaN
# 3             NaN             NaN  ...                NaN                NaN
# 4          Cooper           Regan  ...               Toad              Peach
#
#   PLAYERS_4 [1ST] PLAYERS_4 [2ND] PLAYERS_4 [3RD] PLAYERS_4 [4TH]  \
# 0             NaN             NaN             NaN             NaN
# 1          Cooper          Connor           Blake         Triston
# 2            Cole           Regan          Cooper         Triston
# 3           Regan            Cole          Cooper           Blake
# 4             NaN             NaN             NaN             NaN
#
#   CHARACTERS_4 [1ST] CHARACTERS_4 [2ND] CHARACTERS_4 [3RD] CHARACTERS_4 [4TH]
# 0                NaN                NaN                NaN                NaN
# 1              Luigi               Toad              Peach              Yoshi
# 2               Toad              Yoshi              Mario              Peach
# 3              Yoshi               Toad              Mario              Peach
# 4                NaN                NaN                NaN                NaN
#
# [5 rows x 22 columns]

# %%
form_df.columns = [
    x.replace(" ", "_").replace("[", "").replace("]", "") if x.__contains__("[") else x
    for x in form_df.columns
]

form_df
# Out:
#                Timestamp NEW_SESSION                 MAP  PLAYERS  \
# 0    2024-07-17 19:15:48          NO  Koopa Troopa Beach        3
# 1    2024-07-17 20:01:53          NO      Choco Mountain        4
# 2    2024-07-17 20:15:00          NO       D.K.'s Jungle        4
# 3    2024-07-17 20:42:27          NO     Kalimari Desert        4
# 4    2024-07-17 21:13:04          NO     Frappe Snowland        3
# ...                  ...         ...                 ...      ...
# 2105 2025-01-07 20:52:41          NO     Frappe Snowland        4
# 2106 2025-01-07 21:44:34          NO       Royal Raceway        4
# 2107 2025-01-07 22:04:47          NO     Toad's Turnpike        4
# 2108 2025-01-07 22:18:27          NO        Yoshi Valley        4
# 2109 2025-01-07 22:30:59          NO       Wario Stadium        3
#
#      PLAYERS_2_1ST PLAYERS_2_2ND CHARACTERS_2_1ST CHARACTERS_2_2ND  \
# 0              NaN           NaN              NaN              NaN
# 1              NaN           NaN              NaN              NaN
# 2              NaN           NaN              NaN              NaN
# 3              NaN           NaN              NaN              NaN
# 4              NaN           NaN              NaN              NaN
# ...            ...           ...              ...              ...
# 2105           NaN           NaN              NaN              NaN
# 2106           NaN           NaN              NaN              NaN
# 2107           NaN           NaN              NaN              NaN
# 2108           NaN           NaN              NaN              NaN
# 2109           NaN           NaN              NaN              NaN
#
#      PLAYERS_3_1ST PLAYERS_3_2ND  ... CHARACTERS_3_2ND CHARACTERS_3_3RD  \
# 0           Cooper         Regan  ...            Yoshi             Toad
# 1              NaN           NaN  ...              NaN              NaN
# 2              NaN           NaN  ...              NaN              NaN
# 3              NaN           NaN  ...              NaN              NaN
# 4           Cooper         Regan  ...             Toad            Peach
# ...            ...           ...  ...              ...              ...
# 2105           NaN           NaN  ...              NaN              NaN
# 2106           NaN           NaN  ...              NaN              NaN
# 2107           NaN           NaN  ...              NaN              NaN
# 2108           NaN           NaN  ...              NaN              NaN
# 2109        Cooper         Regan  ...            Peach            Yoshi
#
#      PLAYERS_4_1ST PLAYERS_4_2ND PLAYERS_4_3RD PLAYERS_4_4TH CHARACTERS_4_1ST  \
# 0              NaN           NaN           NaN           NaN              NaN
# 1           Cooper        Connor         Blake       Triston            Luigi
# 2             Cole         Regan        Cooper       Triston             Toad
# 3            Regan          Cole        Cooper         Blake            Yoshi
# 4              NaN           NaN           NaN           NaN              NaN
# ...            ...           ...           ...           ...              ...
# 2105         Regan          Cole        Cooper         Blake             Toad
# 2106         Blake         Regan       Antonio        Connor            Yoshi
# 2107         Regan         Blake       Antonio       Triston             Toad
# 2108       Antonio          Cole        Cooper         Blake            Peach
# 2109           NaN           NaN           NaN           NaN              NaN
#
#      CHARACTERS_4_2ND CHARACTERS_4_3RD CHARACTERS_4_4TH
# 0                 NaN              NaN              NaN
# 1                Toad            Peach            Yoshi
# 2               Yoshi            Mario            Peach
# 3                Toad            Mario            Peach
# 4                 NaN              NaN              NaN
# ...               ...              ...              ...
# 2105            Peach            Mario            Yoshi
# 2106             Toad           Bowser            Peach
# 2107            Yoshi           Bowser            Peach
# 2108             Toad            Yoshi           Bowser
# 2109              NaN              NaN              NaN
#
# [2110 rows x 22 columns]

# %%
fdf = form_df.copy()

# %%
dfs = []

for game_type in [2, 3, 4]:
    tdf = fdf[fdf["PLAYERS"] == game_type].copy().reset_index(drop=True)

    dfs.append(tdf)

# %%
two_p = dfs[0]
three_p = dfs[1]
four_p = dfs[2]

two_p.head()
# Out:
#             Timestamp NEW_SESSION              MAP  PLAYERS PLAYERS_2_1ST  \
# 0 2024-07-18 21:05:00          NO  Toad's Turnpike        2        Cooper
# 1 2024-07-21 16:32:47         YES  Bowser's Castle        2          Matt
# 2 2024-07-21 16:56:38          NO     Yoshi Valley        2          Matt
# 3 2024-07-24 13:46:27         YES    Wario Stadium        2         Regan
# 4 2024-07-24 13:47:06          NO  Toad's Turnpike        2         Regan
#
#   PLAYERS_2_2ND CHARACTERS_2_1ST CHARACTERS_2_2ND PLAYERS_3_1ST PLAYERS_3_2ND  \
# 0         Regan            Peach             Toad           NaN           NaN
# 1        Cooper             Toad            Peach           NaN           NaN
# 2        Cooper            Peach            Yoshi           NaN           NaN
# 3        Martin             Toad            Yoshi           NaN           NaN
# 4        Martin             D.K.            Yoshi           NaN           NaN
#
#    ... CHARACTERS_3_2ND CHARACTERS_3_3RD PLAYERS_4_1ST PLAYERS_4_2ND  \
# 0  ...              NaN              NaN           NaN           NaN
# 1  ...              NaN              NaN           NaN           NaN
# 2  ...              NaN              NaN           NaN           NaN
# 3  ...              NaN              NaN           NaN           NaN
# 4  ...              NaN              NaN           NaN           NaN
#
#   PLAYERS_4_3RD PLAYERS_4_4TH CHARACTERS_4_1ST CHARACTERS_4_2ND  \
# 0           NaN           NaN              NaN              NaN
# 1           NaN           NaN              NaN              NaN
# 2           NaN           NaN              NaN              NaN
# 3           NaN           NaN              NaN              NaN
# 4           NaN           NaN              NaN              NaN
#
#   CHARACTERS_4_3RD CHARACTERS_4_4TH
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN              NaN
#
# [5 rows x 22 columns]

# %%
from typing import Literal


def transform_form_data(
    df: pd.DataFrame, game_type_replace_string: Literal["_2_", "_3_", "_4_"]
) -> pd.DataFrame:

    idf = df.copy()

    idf_out = (
        idf.dropna(axis=1, how="all")
        .reset_index(drop=True)
        .reset_index()
        .rename(columns={"index": "ID"})
    )

    idf_out.columns = [
        (
            x.replace(game_type_replace_string, "_")
            if x.__contains__(game_type_replace_string)
            else x.upper()
        )
        for x in idf_out.columns
    ]

    idf_out["TIMESTAMP"] = (
        pd.to_datetime(idf_out["TIMESTAMP"])
        .dt.tz_localize("US/Eastern")
        .dt.tz_convert("UTC")
    )

    idf_out["ID"] = idf_out["ID"] + 1

    return idf_out

# %%
two_p_out = transform_form_data(df=two_p, game_type_replace_string="_2_")
three_p_out = transform_form_data(df=three_p, game_type_replace_string="_3_")
four_p_out = transform_form_data(df=four_p, game_type_replace_string="_4_")

two_p_out
# Out:
#       ID                 TIMESTAMP NEW_SESSION                MAP  PLAYERS  \
# 0      1 2024-07-19 01:05:00+00:00          NO    Toad's Turnpike        2
# 1      2 2024-07-21 20:32:47+00:00         YES    Bowser's Castle        2
# 2      3 2024-07-21 20:56:38+00:00          NO       Yoshi Valley        2
# 3      4 2024-07-24 17:46:27+00:00         YES      Wario Stadium        2
# 4      5 2024-07-24 17:47:06+00:00          NO    Toad's Turnpike        2
    odf.to_csv(rf"C:\Users\Cooper\sandbox\mkstream\form_data_migration\data_{v}P.csv")

# %%
[len(x) for x in two_p_out["MAP"].unique()]
# Out:
# [15, 15, 12, 13, 13, 14, 15, 18, 12, 13, 13, 17, 12, 15, 13]

# %%
[len(x) for x in four_p_out["MAP"].unique()]
# Out:
# [14, 13, 15, 18, 13, 13, 12, 15, 12, 17, 15, 15, 13, 12, 13]

# %%
cat_df = (
    pd.concat([two_p_out, three_p_out, four_p_out])
    .sort_values(by="TIMESTAMP")
    .drop(columns=["ID"])
    .reset_index(drop=True)
    .reset_index()
    .rename(columns={"index": "ID"})
)[
    [
        "ID",
        "TIMESTAMP",
        "NEW_SESSION",
        "MAP",
        "PLAYERS",
        "PLAYERS_1ST",
        "PLAYERS_2ND",
        "PLAYERS_3RD",
        "PLAYERS_4TH",
        "CHARACTERS_1ST",
        "CHARACTERS_2ND",
        "CHARACTERS_3RD",
        "CHARACTERS_4TH",
    ]
]

cat_df["ID"] = cat_df["ID"] + 1

cat_df.head()
# Out:
#    ID                 TIMESTAMP NEW_SESSION                 MAP  PLAYERS  \
# 0   1 2024-07-17 23:15:48+00:00          NO  Koopa Troopa Beach        3
# 1   2 2024-07-18 00:01:53+00:00          NO      Choco Mountain        4
# 2   3 2024-07-18 00:15:00+00:00          NO       D.K.'s Jungle        4
# 3   4 2024-07-18 00:42:27+00:00          NO     Kalimari Desert        4
# 4   5 2024-07-18 01:13:04+00:00          NO     Frappe Snowland        3
#
#   PLAYERS_1ST PLAYERS_2ND PLAYERS_3RD PLAYERS_4TH CHARACTERS_1ST  \
# 0      Cooper       Regan     Garrett         NaN          Peach
# 1      Cooper      Connor       Blake     Triston          Luigi
# 2        Cole       Regan      Cooper     Triston           Toad
# 3       Regan        Cole      Cooper       Blake          Yoshi
# 4      Cooper       Regan       Blake         NaN          Mario
#
#   CHARACTERS_2ND CHARACTERS_3RD CHARACTERS_4TH
# 0          Yoshi           Toad            NaN
# 1           Toad          Peach          Yoshi
# 2          Yoshi          Mario          Peach
# 3           Toad          Mario          Peach
# 4           Toad          Peach            NaN

# %%
tdf = cat_df.copy()

# %%
def fill_new_session(
    df: pd.DataFrame, drop_window_start_column: bool = True
) -> pd.DataFrame:

    tdf = df.copy()

    # Ensure 'TIMESTAMP' column is in datetime format (UTC)
    tdf["TIMESTAMP"] = pd.to_datetime(tdf["TIMESTAMP"])

    # Create a new column for NEW_SESSION and initially mark all as 'NO'
    tdf["NEW_SESSION"] = "NO"

    # Generate the window start (07:00 UTC) for each game
    tdf["window_start"] = tdf["TIMESTAMP"].dt.floor("D") + pd.Timedelta(hours=7)

    # Iterate through each row to identify the first game in each 24-hour window
    for idx, row in tdf.iterrows():

        window_start = row["window_start"]

        window_end = window_start + pd.Timedelta(days=1) - pd.Timedelta(nanoseconds=1)

        # Get all games within the 24-hour window
        games_in_window = tdf[
            (tdf["TIMESTAMP"] >= window_start) & (tdf["TIMESTAMP"] <= window_end)
        ]

        # Mark the first game in the window as 'YES'
        if row["TIMESTAMP"] == games_in_window["TIMESTAMP"].min():
            tdf.at[idx, "NEW_SESSION"] = "YES"

    if drop_window_start_column:
        tdf = tdf.drop(columns=["window_start"])

    return tdf

# %%
new_sesh = fill_new_session(df=tdf, drop_window_start_column=False)

# %%
new_sesh.to_csv(rf"C:\Users\Cooper\sandbox\mkstream\form_data_migration\temp_hmmm.csv")

# %%
new_sesh.to_clipboard(index=False)

# %%
new_sesh[["ID", "TIMESTAMP", "NEW_SESSION"]]
# Out:
#         ID                 TIMESTAMP NEW_SESSION
# 0        1 2024-07-17 23:15:48+00:00         YES
# 1        2 2024-07-18 00:01:53+00:00          NO
# 2        3 2024-07-18 00:15:00+00:00          NO
# 3        4 2024-07-18 00:42:27+00:00          NO
# 4        5 2024-07-18 01:13:04+00:00          NO
# ...    ...                       ...         ...
# 2105  2106 2025-01-08 01:52:41+00:00          NO
# 2106  2107 2025-01-08 02:44:34+00:00          NO
# 2107  2108 2025-01-08 03:04:47+00:00          NO
# 2108  2109 2025-01-08 03:18:27+00:00          NO
# 2109  2110 2025-01-08 03:30:59+00:00          NO
#
# [2110 rows x 3 columns]

# %%
new_sesh[new_sesh["NEW_SESSION"] != cat_df["NEW_SESSION"]]
# Out:
#         ID                 TIMESTAMP NEW_SESSION                 MAP  PLAYERS  \
# 0        1 2024-07-17 23:15:48+00:00         YES  Koopa Troopa Beach        3
# 329    330 2024-08-12 01:03:28+00:00          NO       Royal Raceway        4
# 404    405 2024-08-18 07:13:37+00:00         YES       Wario Stadium        3
# 406    407 2024-08-18 18:57:00+00:00          NO     Toad's Turnpike        4
# 467    468 2024-08-22 07:20:45+00:00         YES       D.K.'s Jungle        2
# 468    469 2024-08-22 21:39:03+00:00          NO     Toad's Turnpike        4
# 1010  1011 2024-09-28 04:14:46+00:00          NO       Wario Stadium        4
# 1011  1012 2024-09-28 17:36:28+00:00         YES     Toad's Turnpike        4
# 1192  1193 2024-10-15 00:45:57+00:00          NO        Yoshi Valley        4
# 1307  1308 2024-10-25 00:00:34+00:00          NO       D.K.'s Jungle        4
# 1394  1395 2024-10-31 19:51:11+00:00         YES     Toad's Turnpike        4
# 1457  1458 2024-11-04 22:45:51+00:00         YES        Sherbet Land        4
# 1478  1479 2024-11-06 07:01:35+00:00         YES       Mario Raceway        2
# 1481  1482 2024-11-06 23:11:18+00:00          NO        Yoshi Valley        4
# 1528  1529 2024-11-09 18:17:12+00:00         YES  Koopa Troopa Beach        4
# 1586  1587 2024-11-14 01:36:49+00:00          NO     Toad's Turnpike        4
# 1637  1638 2024-11-19 00:09:25+00:00          NO  Koopa Troopa Beach        4
# 1676  1677 2024-11-22 23:28:33+00:00          NO  Koopa Troopa Beach        4
# 1689  1690 2024-11-23 07:17:12+00:00         YES       Wario Stadium        4
# 1692  1693 2024-11-24 04:57:10+00:00          NO     Toad's Turnpike        4
# 324          Peach         Bowser           Toad
# 325           Toad          Yoshi           D.K.
# 326          Peach           Toad         Bowser
# 327          Peach           Toad           D.K.
# 328          Peach           Toad            NaN
# 329         Bowser          Peach          Yoshi
# 330          Peach           Toad            NaN
# 331          Peach           Toad            NaN
# 332           Toad         Bowser          Peach
# 333           Toad          Yoshi            NaN
# 334           Toad          Luigi          Yoshi
# 335          Luigi           Toad          Peach
# 336          Peach         Bowser           Toad
# 337          Yoshi         Bowser           Toad
# 338          Peach         Bowser          Yoshi

# %%
cat_df[["ID", "TIMESTAMP", "NEW_SESSION"]]
# Out:
#         ID                 TIMESTAMP NEW_SESSION
# 0        1 2024-07-17 23:15:48+00:00          NO
# 1        2 2024-07-18 00:01:53+00:00          NO
# 2        3 2024-07-18 00:15:00+00:00          NO
# 3        4 2024-07-18 00:42:27+00:00          NO
# 4        5 2024-07-18 01:13:04+00:00          NO
# ...    ...                       ...         ...
# 2105  2106 2025-01-08 01:52:41+00:00          NO
# 2106  2107 2025-01-08 02:44:34+00:00          NO
# 2107  2108 2025-01-08 03:04:47+00:00          NO
# 2108  2109 2025-01-08 03:18:27+00:00          NO
# 2109  2110 2025-01-08 03:30:59+00:00          NO
#
# [2110 rows x 3 columns]

# %%
cat_df.columns
# Out:
# Index(['ID', 'TIMESTAMP', 'NEW_SESSION', 'MAP', 'PLAYERS', 'PLAYERS_1ST',
#        'PLAYERS_2ND', 'PLAYERS_3RD', 'PLAYERS_4TH', 'CHARACTERS_1ST',
#        'CHARACTERS_2ND', 'CHARACTERS_3RD', 'CHARACTERS_4TH'],
#       dtype='object')

# %%
cat_df
# Out:
#         ID                 TIMESTAMP NEW_SESSION                 MAP  PLAYERS  \
# 0        1 2024-07-17 23:15:48+00:00          NO  Koopa Troopa Beach        3
# 1        2 2024-07-18 00:01:53+00:00          NO      Choco Mountain        4
# 2        3 2024-07-18 00:15:00+00:00          NO       D.K.'s Jungle        4
# 3        4 2024-07-18 00:42:27+00:00          NO     Kalimari Desert        4
# 4        5 2024-07-18 01:13:04+00:00          NO     Frappe Snowland        3
# ...    ...                       ...         ...                 ...      ...
# 2105  2106 2025-01-08 01:52:41+00:00          NO     Frappe Snowland        4
# 2106  2107 2025-01-08 02:44:34+00:00          NO       Royal Raceway        4
# 2107  2108 2025-01-08 03:04:47+00:00          NO     Toad's Turnpike        4
# 2108  2109 2025-01-08 03:18:27+00:00          NO        Yoshi Valley        4
# 2109  2110 2025-01-08 03:30:59+00:00          NO       Wario Stadium        3
#
#      PLAYERS_1ST PLAYERS_2ND PLAYERS_3RD PLAYERS_4TH CHARACTERS_1ST  \
# 0         Cooper       Regan     Garrett         NaN          Peach
# 1         Cooper      Connor       Blake     Triston          Luigi
# 2           Cole       Regan      Cooper     Triston           Toad
# 3          Regan        Cole      Cooper       Blake          Yoshi
# 4         Cooper       Regan       Blake         NaN          Mario
# ...          ...         ...         ...         ...            ...
# 2105       Regan        Cole      Cooper       Blake           Toad
# 2106       Blake       Regan     Antonio      Connor          Yoshi
# 2107       Regan       Blake     Antonio     Triston           Toad
# 2108     Antonio        Cole      Cooper       Blake          Peach
# 2109      Cooper       Regan     Antonio         NaN           Toad
#
#      CHARACTERS_2ND CHARACTERS_3RD CHARACTERS_4TH
# 0             Yoshi           Toad            NaN
# 1              Toad          Peach          Yoshi
# 2             Yoshi          Mario          Peach
# 3              Toad          Mario          Peach
# 4              Toad          Peach            NaN
# ...             ...            ...            ...
# 2105          Peach          Mario          Yoshi
# 2106           Toad         Bowser          Peach
# 2107          Yoshi         Bowser          Peach
# 2108           Toad          Yoshi         Bowser
# 2109          Peach          Yoshi            NaN
#
# [2110 rows x 13 columns]

# %%
cat_df_out = cat_df[
    [
        "ID",
        "TIMESTAMP",
        "NEW_SESSION",
        "MAP",
        "PLAYERS",
        "PLAYERS_1ST",
        "PLAYERS_2ND",
        "PLAYERS_3RD",
        "PLAYERS_4TH",
        "CHARACTERS_1ST",
        "CHARACTERS_2ND",
        "CHARACTERS_3RD",
        "CHARACTERS_4TH",
    ]
].copy()

# %%
cat_df_out
# Out:
#         ID                 TIMESTAMP NEW_SESSION                 MAP  PLAYERS  \
# 0        1 2024-07-17 23:15:48+00:00          NO  Koopa Troopa Beach        3
# 1        2 2024-07-18 00:01:53+00:00          NO      Choco Mountain        4
# 2        3 2024-07-18 00:15:00+00:00          NO       D.K.'s Jungle        4
# 3        4 2024-07-18 00:42:27+00:00          NO     Kalimari Desert        4
# 4        5 2024-07-18 01:13:04+00:00          NO     Frappe Snowland        3
# ...    ...                       ...         ...                 ...      ...
# 2105  2106 2025-01-08 01:52:41+00:00          NO     Frappe Snowland        4
# 2106  2107 2025-01-08 02:44:34+00:00          NO       Royal Raceway        4
# 2107  2108 2025-01-08 03:04:47+00:00          NO     Toad's Turnpike        4
# 2108  2109 2025-01-08 03:18:27+00:00          NO        Yoshi Valley        4
# 2109  2110 2025-01-08 03:30:59+00:00          NO       Wario Stadium        3
#
#      PLAYERS_1ST PLAYERS_2ND PLAYERS_3RD PLAYERS_4TH CHARACTERS_1ST  \
# 0         Cooper       Regan     Garrett         NaN          Peach
# 1         Cooper      Connor       Blake     Triston          Luigi
# 2           Cole       Regan      Cooper     Triston           Toad
# 3          Regan        Cole      Cooper       Blake          Yoshi
# 4         Cooper       Regan       Blake         NaN          Mario
# ...          ...         ...         ...         ...            ...
# 2105       Regan        Cole      Cooper       Blake           Toad
# 2106       Blake       Regan     Antonio      Connor          Yoshi
# 2107       Regan       Blake     Antonio     Triston           Toad
# 2108     Antonio        Cole      Cooper       Blake          Peach
# 2109      Cooper       Regan     Antonio         NaN           Toad
#
#      CHARACTERS_2ND CHARACTERS_3RD CHARACTERS_4TH
# 0             Yoshi           Toad            NaN
# 1              Toad          Peach          Yoshi
# 2             Yoshi          Mario          Peach
# 3              Toad          Mario          Peach
# 4              Toad          Peach            NaN
# ...             ...            ...            ...
# 2105          Peach          Mario          Yoshi
# 2106           Toad         Bowser          Peach
# 2107          Yoshi         Bowser          Peach
# 2108           Toad          Yoshi         Bowser
# 2109          Peach          Yoshi            NaN
#
# [2110 rows x 13 columns]

# %%
cat_df_out.to_csv(rf"C:\Users\Cooper\sandbox\mkstream\form_data_migration\form_data.csv", index=False)

# %%
cat_df_out.drop(columns=["ID"]).to_csv(rf"C:\Users\Cooper\sandbox\mkstream\form_data_migration\form_data_no_id_col.csv", index=False)

# %%
pd.Series([len(x) for x in four_p_out["CHARACTERS_1ST"].unique()]).max()
# Out:
# 6

# %%
four_p_out["CHARACTERS_1ST"].unique()
# Out:
# array(['Luigi', 'Toad', 'Yoshi', 'Wario', 'Peach', 'Mario', 'Bowser',
#        'D.K.'], dtype=object)

# %%
pd.Series([len(x) for x in four_p_out["PLAYERS_1ST"].unique()]).max()
# Out:
# 8

# %% [markdown]
# ## Octets Check

# %%
octets_df = load_data_pd(sheet_name="octets", sheet_id=os.environ["SHEET_ID"])

octets_df = octets_df.drop(
    columns=[
        x
        for x in octets_df.columns
        if x.__contains__("Unnamed")
    ]
)

octets_df
# Out:
#       NAME  COUNT  SEASON  SUID
# 0   Cooper      8       0     1
# 1   Cooper      8       0     4
# 2   Cooper     11       0    10
# 3   Cooper      9       0    13
# 4   Cooper      9       0    19
# ..     ...    ...     ...   ...
# 82   Regan      8      14   848
# 83    Cole      9      14   849
# 84    Luke      8      14   850
# 85  Cooper      9      14   858
# 86  Cooper      8      14   879
#
# [87 rows x 4 columns]

# %%
octets_gb = (
    octets_df.groupby(by=["NAME"])
    .agg(TOTAL_OCTETS=pd.NamedAgg("COUNT", "count"))
    .reset_index()
    .sort_values(by=["TOTAL_OCTETS"], ascending=False)
    .reset_index(drop=True)
)

octets_gb
# Out:
#      NAME  TOTAL_OCTETS
# 0  Cooper            63
# 1    Cole             9
# 2   Regan             5
# 3   Blake             3
# 4  Connor             3
# 5    Matt             3
# 6    Luke             1

# %%
octets_per_season_gb = (
    octets_df.groupby(by=["NAME", "SEASON"])
    .agg(
        TOTAL_OCTETS=pd.NamedAgg("COUNT", "count"),
        SUID_LIST=pd.NamedAgg("SUID", list),
        AVERAGE_WINS_PER_OCTET=pd.NamedAgg("COUNT", "mean"),
        MEDIAN_WINS_PER_OCTET=pd.NamedAgg("COUNT", "median"),
        MAX_WINS=pd.NamedAgg("COUNT", "max"),
    )
    .reset_index()
    .sort_values(by=["SEASON", "TOTAL_OCTETS"], ascending=[True, False])
    .reset_index(drop=True)
)

octets_per_season_gb["SUID_LIST"] = (
    octets_per_season_gb["SUID_LIST"]
    .astype(str)
    .str.replace("[", "")
    .str.replace("]", "")
)

octets_per_season_gb
# Out:
#       NAME  SEASON  TOTAL_OCTETS  \
# 0   Cooper       0             9
# 1    Blake       0             1
# 2     Cole       0             1
# 3   Connor       0             1
# 4    Regan       1             1
# 5   Connor       2             1
# 6   Cooper       2             1
# 7    Regan       2             1
# 8    Blake       3             2
# 9     Cole       3             1
# 10    Matt       3             1
# 11    Cole       5             2
# 12  Connor       5             1
# 13  Cooper       5             1
# 14    Matt       5             1
# 15    Cole       6             1
# 16    Matt       6             1
# 17   Regan       6             1
# 18  Cooper       7             3
# 19    Cole       7             1
# 20  Cooper       8             1
# 21  Cooper       9             3
# 22  Cooper      10            14
# 23  Cooper      11            14
# 24   Regan      11             1
# 25  Cooper      12             8
# 26  Cooper      13             4
# 27    Cole      13             2
# 28  Cooper      14             5
# 29    Cole      14             1
# 30    Luke      14             1
# 31   Regan      14             1
#
#                                             SUID_LIST  AVERAGE_WINS_PER_OCTET  \
# 0                    1, 4, 10, 13, 19, 20, 23, 26, 39                9.111111
# 1                                                  40                9.000000
# 2                                                  38                8.000000
# 3                                                  22                8.000000
# 4                                                  62                8.000000
# 5                                                 210                8.000000
# 6                                                 195                8.000000
# 7                                                 177                9.000000
# 8                                            250, 263                9.000000
# 9                                                 270                8.000000
# 10                                                270               10.000000
# 11                                           363, 365                9.000000
# 12                                                363                8.000000
# 13                                                348                9.000000
# 14                                                360                8.000000
# 15                                                423                8.000000
# 16                                                405                8.000000
# 17                                                435                9.000000
# 18                                      462, 464, 491                8.000000
# 19                                                444                8.000000
# 20                                                511                8.000000
# 21                                      626, 640, 654                8.333333
# 22  668, 670, 675, 676, 683, 685, 690, 691, 696, 6...               10.000000
# 23  714, 715, 719, 723, 725, 726, 728, 731, 732, 7...                9.857143
# 24                                                747                8.000000
# 25             771, 774, 777, 782, 783, 788, 793, 796                8.875000
# 26                                 797, 803, 809, 838                8.750000
# 27                                           803, 808                8.500000
# 28                            842, 845, 847, 858, 879                8.600000
# 29                                                849                9.000000
# 30                                                850                8.000000
# 31                                                848                8.000000
#
#     MEDIAN_WINS_PER_OCTET  MAX_WINS
# 0                     9.0        11
# 1                     9.0         9
# 2                     8.0         8
# 3                     8.0         8
# 4                     8.0         8
# 5                     8.0         8
# 6                     8.0         8
# 7                     9.0         9
# 8                     9.0         9
# 9                     8.0         8
# 10                   10.0        10
# 11                    9.0        10
# 12                    8.0         8
# 13                    9.0         9
# 14                    8.0         8
# 15                    8.0         8
# 16                    8.0         8
# 17                    9.0         9
# 18                    8.0         8
# 19                    8.0         8
# 20                    8.0         8
# 21                    8.0         9
# 22                   10.0        13
# 23                    9.5        13
# 24                    8.0         8
# 25                    8.0        12
# 26                    9.0         9
# 27                    8.5         9
# 28                    9.0         9
# 29                    9.0         9
# 30                    8.0         8
# 31                    8.0         8

# %% [markdown]
# ### Save

# %%
before_or_after = "after"

octets_gb.to_csv(
    rf"C:\Users\Cooper\sandbox\mkstream\form_data_migration\octets_total_groupby_{before_or_after}.csv",
    index=False,
)

octets_per_season_gb.to_csv(
    rf"C:\Users\Cooper\sandbox\mkstream\form_data_migration\octets_per_season_groupby_{before_or_after}.csv",
    index=False,
)

# %% [markdown]
# ### Compare

# %%
octets_gb_before = pd.read_csv(
    r"C:\Users\Cooper\sandbox\mkstream\form_data_migration\octets_total_groupby_before.csv"
)

octets_per_season_gb_before = pd.read_csv(
    r"C:\Users\Cooper\sandbox\mkstream\form_data_migration\octets_per_season_groupby_before.csv"
)

octets_gb_after = pd.read_csv(
    r"C:\Users\Cooper\sandbox\mkstream\form_data_migration\octets_total_groupby_after.csv"
)

octets_per_season_gb_after = pd.read_csv(
    r"C:\Users\Cooper\sandbox\mkstream\form_data_migration\octets_per_season_groupby_after.csv"
)

# %%
octets_gb_after
# Out:
#      NAME  TOTAL_OCTETS
# 0  Cooper            63
# 1    Cole             9
# 2   Regan             5
# 3   Blake             3
# 4  Connor             3
# 5    Matt             3
# 6    Luke             1

# %%
octets_gb_before
# Out:
#      NAME  TOTAL_OCTETS
# 0  Cooper            63
# 1    Cole             9
# 2   Regan             5
# 3   Blake             3
# 4  Connor             3
# 5    Matt             3
# 6    Luke             1

# %%
octets_gb_after == octets_gb_before
# Out:
#    NAME  TOTAL_OCTETS
# 0  True          True
# 1  True          True
# 2  True          True
# 3  True          True
# 4  True          True
# 5  True          True
# 6  True          True

# %%
octets_per_season_gb_after == octets_per_season_gb_before
# Out:
#     NAME  SEASON  TOTAL_OCTETS  SUID_LIST  AVERAGE_WINS_PER_OCTET  \
# 0   True    True          True       True                    True
# 1   True    True          True       True                    True
# 2   True    True          True       True                    True
# 3   True    True          True       True                    True
# 4   True    True          True       True                    True
# 5   True    True          True       True                    True
# 6   True    True          True       True                    True
# 7   True    True          True       True                    True
# 8   True    True          True       True                    True
# 9   True    True          True       True                    True
# 10  True    True          True       True                    True
# 11  True    True          True       True                    True
# 12  True    True          True       True                    True
# 13  True    True          True       True                    True
# 14  True    True          True       True                    True
# 15  True    True          True       True                    True
# 16  True    True          True       True                    True
# 17  True    True          True       True                    True
# 18  True    True          True       True                    True
# 19  True    True          True       True                    True
# 20  True    True          True       True                    True
# 21  True    True          True       True                    True
# 22  True    True          True       True                    True
# 23  True    True          True       True                    True
# 24  True    True          True       True                    True
# 25  True    True          True       True                    True
# 26  True    True          True       True                    True
# 27  True    True          True       True                    True
# 28  True    True          True       True                    True
# 29  True    True          True       True                    True
# 30  True    True          True       True                    True
# 31  True    True          True       True                    True
#
#     MEDIAN_WINS_PER_OCTET  MAX_WINS
# 0                    True      True
# 1                    True      True
# 2                    True      True
# 3                    True      True
# 4                    True      True
# 5                    True      True
# 6                    True      True
# 7                    True      True
# 8                    True      True
# 9                    True      True
# 10                   True      True
# 11                   True      True
# 12                   True      True
# 13                   True      True
# 14                   True      True
# 15                   True      True
# 16                   True      True
# 17                   True      True
# 18                   True      True
# 19                   True      True
# 20                   True      True
# 21                   True      True
# 22                   True      True
# 23                   True      True
# 24                   True      True
# 25                   True      True
# 26                   True      True
# 27                   True      True
# 28                   True      True
# 29                   True      True
# 30                   True      True
# 31                   True      True
